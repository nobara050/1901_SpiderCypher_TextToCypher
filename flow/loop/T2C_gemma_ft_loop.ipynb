# %%
# %%capture
# !pip install accelerate bitsandbytes huggingface_hub transformers func-timeout neo4j

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from func_timeout import func_timeout, FunctionTimedOut
from datetime import datetime
from neo4j import GraphDatabase
import pandas as pd
import torch
import time
import os
import re

# %%
import logging
import warnings
logging.getLogger('neo4j').setLevel(logging.ERROR)
warnings.filterwarnings('ignore', category=FutureWarning)

# %% [markdown]
# **Load model**

# %%
model_id = "neo4j/text2cypher-gemma-2-9b-it-finetuned-2024v1"
max_seq_length = 4096

# BitsAndBytes config cho 4bit quantization
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16,
)

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)

# Load model
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    quantization_config=bnb_config,
    torch_dtype=torch.bfloat16,
    attn_implementation="eager",
    low_cpu_mem_usage=True,
    device_map="auto",
)

model.eval()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/723 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/857 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json:   0%|          | 0.00/39.1k [00:00<?, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.67G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/864M [00:00<?, ?B/s]
# Gemma2ForCausalLM(
#   (model): Gemma2Model(
#     (embed_tokens): Embedding(256000, 3584, padding_idx=0)
#     (layers): ModuleList(
#       (0-41): 42 x Gemma2DecoderLayer(
#         (self_attn): Gemma2Attention(
#           (q_proj): lora.Linear4bit(
#             (base_layer): Linear4bit(in_features=3584, out_features=4096, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.05, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=3584, out_features=64, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=64, out_features=4096, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#             (lora_magnitude_vector): ModuleDict()
#           )
#           (k_proj): lora.Linear4bit(
#             (base_layer): Linear4bit(in_features=3584, out_features=2048, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.05, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=3584, out_features=64, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=64, out_features=2048, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#             (lora_magnitude_vector): ModuleDict()
#           )
#           (v_proj): lora.Linear4bit(
#             (base_layer): Linear4bit(in_features=3584, out_features=2048, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.05, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=3584, out_features=64, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=64, out_features=2048, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#             (lora_magnitude_vector): ModuleDict()
#           )
#           (o_proj): lora.Linear4bit(
#             (base_layer): Linear4bit(in_features=4096, out_features=3584, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.05, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=4096, out_features=64, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=64, out_features=3584, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#             (lora_magnitude_vector): ModuleDict()
#           )
#         )
#         (mlp): Gemma2MLP(
#           (gate_proj): lora.Linear4bit(
#             (base_layer): Linear4bit(in_features=3584, out_features=14336, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.05, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=3584, out_features=64, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=64, out_features=14336, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#             (lora_magnitude_vector): ModuleDict()
#           )
#           (up_proj): lora.Linear4bit(
#             (base_layer): Linear4bit(in_features=3584, out_features=14336, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.05, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=3584, out_features=64, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=64, out_features=14336, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#             (lora_magnitude_vector): ModuleDict()
#           )
#           (down_proj): lora.Linear4bit(
#             (base_layer): Linear4bit(in_features=14336, out_features=3584, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.05, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=14336, out_features=64, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=64, out_features=3584, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#             (lora_magnitude_vector): ModuleDict()
#           )
#           (act_fn): GELUTanh()
#         )
#         (input_layernorm): Gemma2RMSNorm((3584,), eps=1e-06)
#         (post_attention_layernorm): Gemma2RMSNorm((3584,), eps=1e-06)
#         (pre_feedforward_layernorm): Gemma2RMSNorm((3584,), eps=1e-06)
#         (post_feedforward_layernorm): Gemma2RMSNorm((3584,), eps=1e-06)
#       )
#     )
#     (norm): Gemma2RMSNorm((3584,), eps=1e-06)
#     (rotary_emb): Gemma2RotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=3584, out_features=256000, bias=False)
# )

# %% [markdown]
# **Load data**

# %%
checkpoint_path = '/content/drive/MyDrive/T2C_finetune_gemma/finetune_loop_gemma.csv'
test_path = '/content/drive/MyDrive/T2C_finetune_loop_gemma/text2cypher_test.csv'
test_df = pd.read_csv(test_path, encoding="utf-8-sig")

print(f"Loaded test shape: {test_df.shape}")
# Out:
# Loaded test shape: (4833, 6)

# %% [markdown]
# **Neo4j setup**

# %%
URI = "neo4j+s://demo.neo4jlabs.com:7687"

# Danh sách alias
unique_aliases = test_df["database_reference_alias"].dropna().unique().tolist()
DATABASE_ALIASES = unique_aliases

# Lưu trữ drivers theo alias
DRIVERS_BY_ALIAS = {}

# %%
def extract_alias(alias: str):
    name = alias.replace("neo4jlabs_demo_db_", "")
    return name, name

def get_driver(alias):
    if alias in DRIVERS_BY_ALIAS:
        return DRIVERS_BY_ALIAS[alias]
    user, pwd = extract_alias(alias)
    driver = GraphDatabase.driver(URI, auth=(user, pwd))
    DRIVERS_BY_ALIAS[alias] = driver
    return driver

def reset_driver(alias):
    if alias in DRIVERS_BY_ALIAS:
        try:
            DRIVERS_BY_ALIAS[alias].close()
        except Exception as e:
            print(f"Error closing driver: {e}")
        del DRIVERS_BY_ALIAS[alias]
    # Tạo lại driver mới
    return get_driver(alias)

print("✓ Neo4j helper loaded")
# Out:
# ✓ Neo4j helper loaded

# %% [markdown]
# **Prompt Cypher**

# %%
INSTRUCTION_TEMPLATE = (
    "Generate Cypher statement to query a graph database. "
    "Use only the provided relationship types and properties in the schema. \n"
    "Schema: {schema} \n"
    "Question: {question}  \n"
    "Cypher output: "
)

print("✓ INSTRUCTION_TEMPLATE loaded")
# Out:
# ✓ INSTRUCTION_TEMPLATE loaded

# %%
def prompt_cypher(question, schema) -> list[dict]:
    chat = [
        {
            "role": "user",
            "content": INSTRUCTION_TEMPLATE.format(
                schema=schema,
                question=question
            ),
        }
    ]
    return chat

print("✓ prompt_cypher loaded")
# Out:
# ✓ prompt_cypher loaded

# %% [markdown]
# **Generate cypher raw**

# %%
def generate_cypher_raw(question, schema, timeout):
    def _generate():
        # Chuẩn bị chat prompt
        new_message = prompt_cypher(question=question, schema=schema)

        # Apply chat template
        prompt = tokenizer.apply_chat_template(
            new_message,
            add_generation_prompt=True,
            tokenize=False
        )

        # Tokenize
        inputs = tokenizer(prompt, return_tensors="pt", padding=True)
        inputs = inputs.to(model.device)

        # Generation parameters
        model_generate_parameters = {
            "top_p": 0.9,
            "temperature": 0.2,
            "max_new_tokens": 512,
            "do_sample": True,
            "pad_token_id": tokenizer.eos_token_id,
        }

        # Generate - SỬA LỖI Ở ĐÂY
        with torch.no_grad():
            tokens = model.generate(
                input_ids=inputs.input_ids,           # Truyền input_ids
                attention_mask=inputs.attention_mask,  # Truyền attention_mask
                **model_generate_parameters           # Unpack parameters
            )
            # Bỏ phần input prompt
            tokens = tokens[:, inputs.input_ids.shape[1]:]
            # Decode
            raw_output = tokenizer.batch_decode(tokens, skip_special_tokens=True)[0]

        return raw_output

    try:
        return func_timeout(timeout, _generate)
    except FunctionTimedOut:
        print(f"[TIMEOUT] Generation exceeded {timeout}s")
        return "time_error"
    except Exception as e:
        print(f"[ERROR] Generation failed: {e}")
        return "error"

print("✓ generate_cypher_raw loaded")
# Out:
# ✓ generate_cypher_raw loaded

# %% [markdown]
# **Format cypher**

# %%
def postprocess_cypher(output_cypher: str) -> str:
    # Remove explanation
    partition_by = "**Explanation:**"
    output_cypher, _, _ = output_cypher.partition(partition_by)

    # Remove cypher code block markers
    output_cypher = output_cypher.strip("`\n")
    output_cypher = output_cypher.lstrip("cypher\n")
    output_cypher = output_cypher.strip("`\n ")

    return output_cypher

print("✓ postprocess_cypher loaded")
# Out:
# ✓ postprocess_cypher loaded

# %%
def extract_cypher(text):
    if text in ["time_error", "error"]:
        return text

    try:
        # Áp dụng postprocess của Neo4j
        cypher = postprocess_cypher(text)

        # Kiểm tra có MATCH không
        if not cypher.strip():
            return "error"

        cypher_lower = cypher.lower()
        if "match" not in cypher_lower:
            return "error"

        return cypher.strip()

    except Exception as e:
        print(f"[ERROR] Extract failed: {e}")
        return "error"

print("✓ extract_cypher loaded")
# Out:
# ✓ extract_cypher loaded

# %% [markdown]
# **Generate cypher**

# %%
def generate_cypher(question, schema, timeout=300):
    # Generate raw output
    raw_output = generate_cypher_raw(question, schema, timeout)

    # Extract Cypher
    cypher = extract_cypher(raw_output)

    return cypher

print("✓ generate_cypher loaded")
# Out:
# ✓ generate_cypher loaded

# %% [markdown]
# **Prompt Self Correction**

# %%
def prompt_correction(schema, question, cypher_current, error) -> list[dict]:
    # AUTO-HINT MECHANISM - GENERAL INSTRUCTIONS WITH COT
    additional_hint = ""

    # Lỗi Syntax Error chung
    if "syntax error" in error.lower() or "invalid syntax" in error.lower():
        additional_hint = """
CRITICAL: Syntax error detected. Follow these steps to fix:

Step 1 - ANALYZE the error message:
- Identify which keyword/token is causing the error
- Check the position (line, column) where error occurs
- Understand what the parser expected at that position

Step 2 - COMMON SYNTAX RULES in Cypher:
- WHERE clause MUST come BEFORE RETURN, never after RETURN
- If you need multiple conditions, combine them with AND/OR in the same WHERE clause
- WITH clause cannot be the last clause - must be followed by RETURN or another clause
- RETURN must be the final clause (unless using UNION or other set operations)
- Cypher does NOT support GROUP BY - use aggregation functions in WITH instead
- Pattern expressions in WHERE must use pattern comprehension: SIZE([(pattern) | var])

Step 3 - FIX the query:
- Move misplaced clauses to correct position
- Combine multiple WHERE clauses into one
- Add missing RETURN if query ends with WITH
- Remove unsupported SQL syntax (GROUP BY, HAVING, etc.)

Example of common mistakes:
WRONG: MATCH (n) WHERE condition1 RETURN n WHERE condition2
CORRECT: MATCH (n) WHERE condition1 AND condition2 RETURN n

WRONG: WITH n.property, COUNT(*) AS count
CORRECT: WITH n.property AS property, COUNT(*) AS count
"""

    # Lỗi Unknown/Missing properties hoặc labels
    elif "unknown" in error.lower() or "does not exist" in error.lower() or "not found" in error.lower():
        additional_hint = """
CRITICAL: Unknown label/property detected. Follow these steps to fix:

Step 1 - IDENTIFY what is missing:
- Check if you're using a label that doesn't exist
- Check if you're accessing a property that doesn't exist
- Verify the entity type: is it a node property or relationship property?

Step 2 - VERIFY against schema:
- Node properties are listed under "Nodes" section
- Relationship properties are listed under "Relationships" section
- Labels use colon syntax (:Label), properties use dot syntax (variable.property)

Step 3 - FIX the query:
- Use correct property name from schema
- Access property from correct entity (node vs relationship)
- Replace incorrect label syntax with property access

Example of common mistakes:
WRONG: MATCH (n) WHERE n:`propertyName` = value
CORRECT: MATCH (n) WHERE n.propertyName = value

WRONG: Using relationship variable for node property: AVG(rel.nodeProperty)
CORRECT: Using node variable for node property: AVG(node.nodeProperty)
"""

    # Lỗi Expression/Aliasing
    elif "must be aliased" in error.lower() or "alias" in error.lower():
        additional_hint = """
CRITICAL: Aliasing error detected. Follow these steps to fix:

Step 1 - UNDERSTAND aliasing rules:
- In WITH clause, expressions must be aliased using AS
- Property expressions cannot be used directly without aliasing
- Aggregation results must be aliased

Step 2 - TWO APPROACHES to fix:
Approach A - Alias each property:
  WITH node.prop1 AS prop1, node.prop2 AS prop2, AGG(...) AS result

Approach B - Use node variable:
  WITH node, AGG(...) AS result
  RETURN node.prop1, node.prop2, result

Step 3 - CHOOSE the simpler approach:
- If you need many properties: use Approach B (pass entire node)
- If you need few properties: use Approach A (alias each one)
"""

    # Lỗi Pattern/Structure
    elif "pattern" in error.lower() or "cannot conclude" in error.lower():
        additional_hint = """
CRITICAL: Query structure error detected. Follow these steps to fix:

Step 1 - CHECK query structure:
- Does the query end with a proper clause? (RETURN, CREATE, DELETE, etc.)
- Are pattern expressions used correctly?
- Is SIZE() used with pattern comprehension?

Step 2 - COMMON STRUCTURE RULES:
- Query MUST end with RETURN (or update clause)
- WITH ... ORDER BY ... LIMIT MUST be followed by RETURN
- Pattern in SIZE() needs comprehension: SIZE([(pattern) | var]) not SIZE((pattern))
- Pattern existence check: use EXISTS { (pattern) } in WHERE

Step 3 - FIX based on rule violated:
- Add RETURN clause if missing
- Wrap pattern in comprehension for SIZE()
- Change to EXISTS if only checking presence

Example of common mistakes:
WRONG: WITH node, COUNT(*) AS count ORDER BY count LIMIT 10
CORRECT: WITH node, COUNT(*) AS count ORDER BY count LIMIT 10 RETURN node, count

WRONG: WHERE SIZE((a)-[:REL]->(b)) > 5
CORRECT: WHERE SIZE([(a)-[:REL]->(b) | a]) > 5
"""

    # BUILD CORRECTION TEMPLATE WITH COT HINT
    correction_content = (
        "You are an expert at fixing Cypher queries. Analyze the error carefully and fix the query.\n\n"
        f"Schema:\n{schema}\n\n"
        f"Original Question: {question}\n\n"
        f"Wrong Cypher Query:\n{cypher_current}\n\n"
        f"Error Message:\n{error}\n"
    )

    # Thêm hint nếu có
    if additional_hint:
        correction_content += f"\n{additional_hint}\n"

    correction_content += "\nFollow the steps above to analyze and fix the query. Return ONLY the corrected Cypher statement, no explanations.\n\nCorrected Cypher output: "

    chat = [
        {
            "role": "user",
            "content": correction_content
        }
    ]
    return chat

print("✓ prompt_correction loaded")
# Out:
# ✓ prompt_correction loaded

# %% [markdown]
# **Neo4j Execution**

# %%
def execute_cypher(cypher_query, alias, timeout=180):
    if cypher_query in ["error", "time_error", None, ""]:
        return (False, "Invalid cypher query")

    driver = get_driver(alias)

    try:
        with driver.session() as session:
            # Chỉ execute query, KHÔNG consume result
            session.run(cypher_query, timeout=timeout)
            return (True, None)
    except Exception as e:
        error_msg = str(e)
        # Nếu lỗi authentication, reset driver
        if "authentication" in error_msg.lower() or "unauthorized" in error_msg.lower():
            reset_driver(alias)
        return (False, error_msg)

print("✓ execute_cypher loaded")
# Out:
# ✓ execute_cypher loaded

# %%
def explain_cypher(cypher_query, driver, timeout=180):
    if cypher_query in ["error", None, ""]:
        return (False, "Invalid cypher query")

    try:
        with driver.session() as session:
            explain_query = f"EXPLAIN {cypher_query}"
            session.run(explain_query, timeout=timeout)
            return (True, None)
    except Exception as e:
        return (False, str(e))

print("✓ explain_cypher loaded")
# Out:
# ✓ explain_cypher loaded

# %% [markdown]
# **Setup model Self Loop**

# %%
def llm_correct_cypher(schema, question, cypher_current, error, timeout=300):
    def _correct():
        messages = prompt_correction(
            schema=schema,
            question=question,
            cypher_current=cypher_current,
            error=error
        )

        prompt = tokenizer.apply_chat_template(
            messages,
            add_generation_prompt=True,
            tokenize=False
        )

        inputs = tokenizer(prompt, return_tensors="pt", padding=True)
        inputs = inputs.to(model.device)

        model_generate_parameters = {
            "top_p": 0.9,
            "temperature": 0.1,
            "max_new_tokens": 512,
            "do_sample": True,
            "pad_token_id": tokenizer.eos_token_id,
        }

        with torch.no_grad():
            tokens = model.generate(
                input_ids=inputs.input_ids,
                attention_mask=inputs.attention_mask,
                **model_generate_parameters
            )
            tokens = tokens[:, inputs.input_ids.shape[1]:]
            raw_output = tokenizer.batch_decode(tokens, skip_special_tokens=True)[0]

        corrected_cypher = extract_cypher(raw_output)

        return corrected_cypher

    try:
        return func_timeout(timeout, _correct)
    except FunctionTimedOut:
        return "time_error"
    except Exception as e:
        return "error"

# %% [markdown]
# **Hàm loop**

# %%
def cypher_self_correction(
    cypher_initial,
    alias,
    schema_context,
    question,
    max_retries=3,
    timeout=900
):
    cypher_current = cypher_initial
    retry = 0
    errors_history = []

    while retry < max_retries:
        success, error = execute_cypher(cypher_current, alias, timeout=timeout)

        if success:
            return {
                "success": True,
                "final_cypher": cypher_current,
                "retries": retry,
                "errors": errors_history
            }

        errors_history.append(f"Retry {retry}: {error}")

        cypher_corrected = llm_correct_cypher(
            schema=schema_context,
            question=question,
            cypher_current=cypher_current,
            error=error
        )

        if cypher_corrected in ["error", "time_error", None, ""]:
            break

        cypher_current = cypher_corrected
        retry += 1

    return {
        "success": False,
        "final_cypher": cypher_current,
        "retries": retry,
        "errors": errors_history
    }

# %%
def cypher_explain_correction(
    cypher_initial,
    driver,
    schema_context,
    question,
    max_retries=3,
    timeout=900
):
    cypher_current = cypher_initial
    retry = 0
    errors_history = []

    while retry < max_retries:
        success, error = explain_cypher(cypher_current, driver, timeout=timeout)

        if success:
            return {
                "success": True,
                "final_cypher": cypher_current,
                "retries": retry,
                "errors": errors_history
            }

        errors_history.append(f"Retry {retry}: {error}")

        cypher_corrected = llm_correct_cypher(
            schema=schema_context,
            question=question,
            cypher_current=cypher_current,
            error=error
        )

        if cypher_corrected in ["error", "time_error", None, ""]:
            break

        cypher_current = cypher_corrected
        retry += 1

    return {
        "success": False,
        "final_cypher": cypher_current,
        "retries": retry,
        "errors": errors_history
    }

# %% [markdown]
# **Luồng toàn cục**

# %%
def generate_cypher_with_correction(
    question,
    schema,
    alias,
    max_retries=3,
    timeout=1200,
    neo4j_timeout=180
):
    # Kiểm tra alias trước
    if pd.isna(alias) or alias is None or alias == "" or (isinstance(alias, str) and alias.strip() == ""):
        # Nếu alias không hợp lệ, sử dụng syntax validation với EXPLAIN
        def _execute_validation():
            cypher_initial = generate_cypher(question, schema)

            if cypher_initial in ["error", None]:
                return {
                    "cypher_initial": "error",
                    "schema": schema,
                    "correction_result": None,
                    "final_cypher": "error",
                    "success": False,
                    "retries": 0,
                    "errors": ["Failed to generate initial cypher"]
                }

            # Lấy driver đầu tiên để validate syntax
            first_alias = list(DRIVERS_BY_ALIAS.keys())[0] if DRIVERS_BY_ALIAS else DATABASE_ALIASES[0]
            driver = get_driver(first_alias)

            # Syntax validation loop với EXPLAIN
            validation_result = cypher_explain_correction(
                cypher_initial=cypher_initial,
                driver=driver,
                schema_context=schema,
                question=question,
                max_retries=max_retries,
                timeout=neo4j_timeout
            )

            final_cypher = validation_result.get("final_cypher")
            if final_cypher is None:
                final_cypher = "error"

            return {
                "cypher_initial": cypher_initial,
                "schema": schema,
                "correction_result": validation_result,
                "final_cypher": final_cypher,
                "success": validation_result.get("success"),
                "retries": validation_result.get("retries"),
                "errors": validation_result.get("errors")
            }

        try:
            result = func_timeout(timeout, _execute_validation)
            return result

        except FunctionTimedOut:
            return {
                "cypher_initial": "error",
                "schema": schema,
                "correction_result": None,
                "final_cypher": "error",
                "success": False,
                "retries": 0,
                "errors": [f"Total timeout reached after {timeout}s"]
            }
        except Exception as e:
            return {
                "cypher_initial": "error",
                "schema": schema,
                "correction_result": None,
                "final_cypher": "error",
                "success": False,
                "retries": 0,
                "errors": [f"Unexpected error: {str(e)}"]
            }

    # Alias hợp lệ - chạy execution thật
    def _execute_generation():
        cypher_initial = generate_cypher(question, schema)

        if cypher_initial in ["error", None]:
            return {
                "cypher_initial": "error",
                "schema": schema,
                "correction_result": None,
                "final_cypher": "error",
                "success": False,
                "retries": 0,
                "errors": ["Failed to generate initial cypher"]
            }

        # Self-correction loop
        correction_result = cypher_self_correction(
            cypher_initial=cypher_initial,
            alias=alias,
            schema_context=schema,
            question=question,
            max_retries=max_retries,
            timeout=neo4j_timeout
        )

        final_cypher = correction_result.get("final_cypher")
        if final_cypher is None:
            final_cypher = "error"

        return {
            "cypher_initial": cypher_initial,
            "schema": schema,
            "correction_result": correction_result,
            "final_cypher": final_cypher,
            "success": correction_result.get("success"),
            "retries": correction_result.get("retries"),
            "errors": correction_result.get("errors")
        }

    try:
        result = func_timeout(timeout, _execute_generation)
        return result

    except FunctionTimedOut:
        return {
            "cypher_initial": "error",
            "schema": schema,
            "correction_result": None,
            "final_cypher": "error",
            "success": False,
            "retries": 0,
            "errors": [f"Total timeout reached after {timeout}s"]
        }
    except Exception as e:
        return {
            "cypher_initial": "error",
            "schema": schema,
            "correction_result": None,
            "final_cypher": "error",
            "success": False,
            "retries": 0,
            "errors": [f"Unexpected error: {str(e)}"]
        }

# %%
# Lấy test case
first_row = test_df.iloc[0]
test_question = first_row['question']
test_schema = first_row['schema']
test_alias = first_row['database_reference_alias']

print("="*80)
print("TEST QUESTION:")
print("="*80)
print(test_question)

# Test 1: Extracted Cypher
print("\n" + "="*80)
print("TEST 1: generate_cypher() - EXTRACTED")
print("="*80)
result = generate_cypher_with_correction(
        question=test_question,
        schema=test_schema,
        alias=test_alias,
        max_retries=3,
        timeout=1200,
        neo4j_timeout=60
    )
print(f"Success: {result['success']}")
print(f"Retries: {result['retries']}")
print(f"Cypher Initial: {result['cypher_initial']}")
print(f"Final Cypher:\n{result['final_cypher']}")
if result["errors"]:
    print("Errors:")
    for e in result["errors"]:
        print(e)

# Test 2: Expected
print("\n" + "="*80)
print("TEST 2: EXPECTED CYPHER")
print("="*80)
print(first_row['cypher'])
# Out:
# ================================================================================
# TEST QUESTION:
# ================================================================================
# Identify the 5 suppliers with the highest average unit price of products supplied.
#
# ================================================================================
# TEST 1: generate_cypher() - EXTRACTED
# ================================================================================
# Success: True
# Retries: 0
# Cypher Initial: MATCH (s:Supplier)<-[:SUPPLIES]-(p:Product) WITH s, avg(toFloat(p.unitPrice)) AS avgUnitPrice ORDER BY avgUnitPrice DESC LIMIT 5 RETURN s.companyName AS supplierName, avgUnitPrice
# Final Cypher:
# MATCH (s:Supplier)<-[:SUPPLIES]-(p:Product) WITH s, avg(toFloat(p.unitPrice)) AS avgUnitPrice ORDER BY avgUnitPrice DESC LIMIT 5 RETURN s.companyName AS supplierName, avgUnitPrice
#
# ================================================================================
# TEST 2: EXPECTED CYPHER
# ================================================================================
# MATCH (s:Supplier)-[:SUPPLIES]->(p:Product) WITH s, avg(p.unitPrice) AS avgUnitPrice ORDER BY avgUnitPrice DESC LIMIT 5 RETURN s.companyName AS Supplier, avgUnitPrice AS AverageUnitPrice

# %% [markdown]
# **Chạy batch**

# %%
def run_batch_with_correction(
    test_df,
    checkpoint_path,
    max_retries=3,
    timeout=1200,
    neo4j_timeout=60,
    log_interval=100,
    save_interval=50
):
    """
    Chạy generation với self-correction và checkpoint support
    """
    # ==========================================================================
    # BƯỚC 1: Kiểm tra và load checkpoint
    if os.path.exists(checkpoint_path):
        print(f"[CHECKPOINT] Tìm thấy file checkpoint: {checkpoint_path}")
        df = pd.read_csv(checkpoint_path, encoding="utf-8-sig")
        print(f"[CHECKPOINT] Đã load {len(df)} dòng từ checkpoint")

        processed_count = df['cypher_generated'].notna().sum()
        print(f"[CHECKPOINT] Đã xử lý: {processed_count}/{len(df)} dòng")

    else:
        print(f"[CHECKPOINT] Không tìm thấy checkpoint, tạo mới từ test_df")
        df = test_df.copy()
        df['cypher_generated'] = ''
        df['success'] = ''
        df['retries'] = ''
        df['errors'] = ''

        df.to_csv(checkpoint_path, index=False, encoding='utf-8')
        print(f"[CHECKPOINT] Đã tạo file checkpoint: {checkpoint_path}")

    # ==========================================================================
    # BƯỚC 2: Xử lý các dòng chưa có kết quả
    total_rows = len(df)

    success_count = 0
    error_count = 0
    timeout_error_count = 0
    batch_start_idx = 0

    processed_since_last_save = 0

    print(f"\n{'='*80}")
    print(f"BẮT ĐẦU XỬ LÝ - Tổng số dòng: {total_rows}")
    print(f"Model: neo4j/text2cypher-gemma-2-9b-it-finetuned-2024v1")
    print(f"Self-correction: max_retries={max_retries}, neo4j_timeout={neo4j_timeout}s")
    print(f"{'='*80}\n")

    start_time = time.time()

    for idx in range(total_rows):
        current_cypher = df.at[idx, 'cypher_generated']

        if pd.notna(current_cypher) and str(current_cypher).strip() != '':
            continue

        # ======================================================================
        # XỬ LÝ DÒNG CHƯA CÓ KẾT QUẢ
        print(f"[Processing] Dòng {idx}...", end=" ", flush=True)

        try:
            question = df.at[idx, 'question']
            schema = df.at[idx, 'schema']
            alias = df.at[idx, 'database_reference_alias']

            result = generate_cypher_with_correction(
                question=question,
                schema=schema,
                alias=alias,
                max_retries=max_retries,
                timeout=timeout,
                neo4j_timeout=neo4j_timeout
            )

            df.at[idx, 'cypher_generated'] = result['final_cypher']
            df.at[idx, 'success'] = result['success']
            df.at[idx, 'retries'] = result['retries']
            df.at[idx, 'errors'] = str(result['errors'])

            cypher_result = result['final_cypher']

            if cypher_result == "error":
                error_count += 1
                print("ERROR")
            elif cypher_result == "time_error":
                timeout_error_count += 1
                print("TIMEOUT")
            else:
                success_count += 1
                print(f"SUCCESS (retries: {result['retries']})")

            processed_since_last_save += 1

        except Exception as e:
            print(f"ERROR - {str(e)}")
            df.at[idx, 'cypher_generated'] = "error"
            df.at[idx, 'success'] = False
            df.at[idx, 'retries'] = 0
            df.at[idx, 'errors'] = str(e)
            error_count += 1
            processed_since_last_save += 1

        # ======================================================================
        # LƯU CHECKPOINT
        # ======================================================================
        if processed_since_last_save >= save_interval:
            df.to_csv(checkpoint_path, index=False, encoding='utf-8')
            print(f"[CHECKPOINT] Đã lưu sau {processed_since_last_save} dòng")
            processed_since_last_save = 0

        # ======================================================================
        # LOG THỐNG KÊ
        # ======================================================================
        if (idx + 1) % log_interval == 0:
            elapsed_time = time.time() - start_time
            avg_time_per_row = elapsed_time / (idx + 1)
            remaining_rows = total_rows - (idx + 1)
            estimated_time = avg_time_per_row * remaining_rows

            print(f"\n{'='*80}")
            print(f"[LOG] Dòng {batch_start_idx}-{idx}")
            print(f"{'='*80}")
            print(f"Thành công:     {success_count}")
            print(f"Error:          {error_count}")
            print(f"Timeout Error:  {timeout_error_count}")
            print(f"Tổng xử lý:     {success_count + error_count + timeout_error_count}")
            print(f"Tiến độ:        {idx + 1}/{total_rows} ({(idx + 1)/total_rows*100:.2f}%)")
            print(f"Thời gian:      {elapsed_time/60:.2f} phút")
            print(f"Ước tính còn:   {estimated_time/60:.2f} phút")
            print(f"{'='*80}\n")

            success_count = 0
            error_count = 0
            timeout_error_count = 0
            batch_start_idx = idx + 1

    # ==========================================================================
    # LƯU CHECKPOINT CUỐI CÙNG
    # ==========================================================================
    if processed_since_last_save > 0:
        df.to_csv(checkpoint_path, index=False, encoding='utf-8')
        print(f"[CHECKPOINT] Đã lưu {processed_since_last_save} dòng cuối cùng")

    # ==========================================================================
    # KẾT THÚC - LOG CUỐI CÙNG
    # ==========================================================================
    total_time = time.time() - start_time

    final_success = (df['cypher_generated'].notna() &
                     (df['cypher_generated'] != 'error') &
                     (df['cypher_generated'] != 'time_error') &
                     (df['cypher_generated'] != '')).sum()
    final_error = (df['cypher_generated'] == 'error').sum()
    final_timeout = (df['cypher_generated'] == 'time_error').sum()

    print(f"\n{'='*80}")
    print(f"HOÀN THÀNH")
    print(f"{'='*80}")
    print(f"Tổng số dòng:        {total_rows}")
    print(f"Thành công:          {final_success} ({final_success/total_rows*100:.2f}%)")
    print(f"Error:               {final_error} ({final_error/total_rows*100:.2f}%)")
    print(f"Timeout Error:       {final_timeout} ({final_timeout/total_rows*100:.2f}%)")
    print(f"Tổng thời gian:      {total_time/60:.2f} phút")
    print(f"Thời gian trung bình: {total_time/total_rows:.2f} giây/dòng")
    print(f"Kết quả đã lưu tại:  {checkpoint_path}")
    print(f"{'='*80}\n")

    return df

print("✓ run_batch_with_correction loaded")
# Out:
# ✓ run_batch_with_correction loaded

# %%
df_results = run_batch_with_correction(
    test_df=test_df,
    checkpoint_path=checkpoint_path,
    max_retries=3,
    timeout=1200,
    neo4j_timeout=60,
    log_interval=100,
    save_interval=50
)
# Out:
# [CHECKPOINT] Tìm thấy file checkpoint: /content/drive/MyDrive/T2C_finetune_gemma/finetune_gemma.csv
# [CHECKPOINT] Đã load 4833 dòng từ checkpoint
# [CHECKPOINT] Đã xử lý: 4100/4833 dòng
#
# ================================================================================
# BẮT ĐẦU XỬ LÝ - Tổng số dòng: 4833
# Model: neo4j/text2cypher-gemma-2-9b-it-finetuned-2024v1
# Self-correction: max_retries=3, neo4j_timeout=60s
# ================================================================================
#
# [Processing] Dòng 4100... SUCCESS (retries: 0)
# [Processing] Dòng 4101... SUCCESS (retries: 0)
# [Processing] Dòng 4102... SUCCESS (retries: 0)
# [Processing] Dòng 4103... SUCCESS (retries: 0)
# [Processing] Dòng 4104... SUCCESS (retries: 0)
# [Processing] Dòng 4105... SUCCESS (retries: 0)
# [Processing] Dòng 4106... SUCCESS (retries: 0)
# [Processing] Dòng 4107... SUCCESS (retries: 0)
# [Processing] Dòng 4108... SUCCESS (retries: 0)
# [Processing] Dòng 4109... SUCCESS (retries: 0)
# [Processing] Dòng 4110... SUCCESS (retries: 0)
# [Processing] Dòng 4111... SUCCESS (retries: 0)
# [Processing] Dòng 4112... SUCCESS (retries: 0)
# [Processing] Dòng 4113... SUCCESS (retries: 0)
# [Processing] Dòng 4114... SUCCESS (retries: 0)
# [Processing] Dòng 4115... SUCCESS (retries: 0)
# [Processing] Dòng 4116... SUCCESS (retries: 0)
# [Processing] Dòng 4117... SUCCESS (retries: 1)
# [Processing] Dòng 4118... SUCCESS (retries: 0)
# [Processing] Dòng 4119... SUCCESS (retries: 0)
# [Processing] Dòng 4120... SUCCESS (retries: 3)
# [Processing] Dòng 4121... SUCCESS (retries: 0)
# [Processing] Dòng 4122... SUCCESS (retries: 0)
# [Processing] Dòng 4123... SUCCESS (retries: 0)
# [Processing] Dòng 4124... SUCCESS (retries: 0)
# [Processing] Dòng 4125... SUCCESS (retries: 0)
# [Processing] Dòng 4126... SUCCESS (retries: 0)
# [Processing] Dòng 4127... SUCCESS (retries: 0)
# [Processing] Dòng 4128... SUCCESS (retries: 0)
# [Processing] Dòng 4129... SUCCESS (retries: 3)
# [Processing] Dòng 4130... SUCCESS (retries: 0)
# [Processing] Dòng 4131... SUCCESS (retries: 0)
# [Processing] Dòng 4132... SUCCESS (retries: 0)
# [Processing] Dòng 4133... SUCCESS (retries: 0)
# [Processing] Dòng 4134... SUCCESS (retries: 0)
# [Processing] Dòng 4135... SUCCESS (retries: 0)
# [Processing] Dòng 4136... SUCCESS (retries: 0)
# [Processing] Dòng 4137... SUCCESS (retries: 0)
# [Processing] Dòng 4138... SUCCESS (retries: 0)
# [Processing] Dòng 4139... SUCCESS (retries: 0)
# [Processing] Dòng 4140... SUCCESS (retries: 0)
# [Processing] Dòng 4141... SUCCESS (retries: 0)
# [Processing] Dòng 4142... SUCCESS (retries: 0)
# [Processing] Dòng 4143... SUCCESS (retries: 0)
# [Processing] Dòng 4144... SUCCESS (retries: 0)
# [Processing] Dòng 4145... SUCCESS (retries: 3)
# [Processing] Dòng 4146... SUCCESS (retries: 0)
# [Processing] Dòng 4147... SUCCESS (retries: 0)
# [Processing] Dòng 4148... SUCCESS (retries: 0)
# [Processing] Dòng 4149... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
# [Processing] Dòng 4150... SUCCESS (retries: 0)
# [Processing] Dòng 4151... SUCCESS (retries: 0)
# [Processing] Dòng 4152... SUCCESS (retries: 1)
# [Processing] Dòng 4153... SUCCESS (retries: 0)
# [Processing] Dòng 4154... SUCCESS (retries: 0)
# [Processing] Dòng 4155... SUCCESS (retries: 0)
# [Processing] Dòng 4156... SUCCESS (retries: 0)
# [Processing] Dòng 4157... SUCCESS (retries: 0)
# [Processing] Dòng 4158... SUCCESS (retries: 0)
# [Processing] Dòng 4159... SUCCESS (retries: 0)
# [Processing] Dòng 4160... SUCCESS (retries: 0)
# [Processing] Dòng 4161... SUCCESS (retries: 0)
# [Processing] Dòng 4162... SUCCESS (retries: 3)
# [Processing] Dòng 4163... SUCCESS (retries: 0)
# [Processing] Dòng 4164... SUCCESS (retries: 0)
# [Processing] Dòng 4165... SUCCESS (retries: 0)
# [Processing] Dòng 4166... SUCCESS (retries: 0)
# [Processing] Dòng 4167... SUCCESS (retries: 0)
# [Processing] Dòng 4168... SUCCESS (retries: 0)
# [Processing] Dòng 4169... SUCCESS (retries: 0)
# [Processing] Dòng 4170... SUCCESS (retries: 0)
# [Processing] Dòng 4171... SUCCESS (retries: 0)
# [Processing] Dòng 4172... SUCCESS (retries: 0)
# [Processing] Dòng 4173... SUCCESS (retries: 0)
# [Processing] Dòng 4174... SUCCESS (retries: 0)
# [Processing] Dòng 4175... SUCCESS (retries: 0)
# [Processing] Dòng 4176... SUCCESS (retries: 0)
# [Processing] Dòng 4177... SUCCESS (retries: 0)
# [Processing] Dòng 4178... SUCCESS (retries: 0)
# [Processing] Dòng 4179... SUCCESS (retries: 0)
# [Processing] Dòng 4180... SUCCESS (retries: 0)
# [Processing] Dòng 4181... SUCCESS (retries: 0)
# [Processing] Dòng 4182... SUCCESS (retries: 0)
# [Processing] Dòng 4183... SUCCESS (retries: 0)
# [Processing] Dòng 4184... SUCCESS (retries: 0)
# [Processing] Dòng 4185... SUCCESS (retries: 0)
# [Processing] Dòng 4186... SUCCESS (retries: 0)
# [Processing] Dòng 4187... SUCCESS (retries: 0)
# [Processing] Dòng 4188... SUCCESS (retries: 0)
# [Processing] Dòng 4189... SUCCESS (retries: 0)
# [Processing] Dòng 4190... SUCCESS (retries: 0)
# [Processing] Dòng 4191... SUCCESS (retries: 0)
# [Processing] Dòng 4192... SUCCESS (retries: 0)
# [Processing] Dòng 4193... SUCCESS (retries: 0)
# [Processing] Dòng 4194... SUCCESS (retries: 0)
# [Processing] Dòng 4195... SUCCESS (retries: 0)
# [Processing] Dòng 4196... SUCCESS (retries: 0)
# [Processing] Dòng 4197... SUCCESS (retries: 0)
# [Processing] Dòng 4198... SUCCESS (retries: 0)
# [Processing] Dòng 4199... SUCCESS (retries: 3)
# [CHECKPOINT] Đã lưu sau 50 dòng
#
# ================================================================================
# [LOG] Dòng 0-4199
# ================================================================================
# Thành công:     100
# Error:          0
# Timeout Error:  0
# Tổng xử lý:     100
# Tiến độ:        4200/4833 (86.90%)
# Thời gian:      36.93 phút
# Ước tính còn:   5.57 phút
# ================================================================================
#
# [Processing] Dòng 4200... SUCCESS (retries: 0)
# [Processing] Dòng 4201... SUCCESS (retries: 0)
# [Processing] Dòng 4202... SUCCESS (retries: 0)
# [Processing] Dòng 4203... SUCCESS (retries: 0)
# [Processing] Dòng 4204... SUCCESS (retries: 0)
# [Processing] Dòng 4205... SUCCESS (retries: 0)
# [Processing] Dòng 4206... SUCCESS (retries: 0)
# [Processing] Dòng 4207... SUCCESS (retries: 0)
# [Processing] Dòng 4208... SUCCESS (retries: 0)
# [Processing] Dòng 4209... SUCCESS (retries: 0)
# [Processing] Dòng 4210... SUCCESS (retries: 0)
# [Processing] Dòng 4211... SUCCESS (retries: 0)
# [Processing] Dòng 4212... SUCCESS (retries: 0)
# [Processing] Dòng 4213... SUCCESS (retries: 0)
# [Processing] Dòng 4214... SUCCESS (retries: 0)
# [Processing] Dòng 4215... SUCCESS (retries: 0)
# [Processing] Dòng 4216... SUCCESS (retries: 0)
# [Processing] Dòng 4217... SUCCESS (retries: 0)
# [Processing] Dòng 4218... SUCCESS (retries: 0)
# [Processing] Dòng 4219... SUCCESS (retries: 0)
# [Processing] Dòng 4220... SUCCESS (retries: 3)
# [Processing] Dòng 4221... SUCCESS (retries: 0)
# [Processing] Dòng 4222... SUCCESS (retries: 0)
# [Processing] Dòng 4223... SUCCESS (retries: 0)
# [Processing] Dòng 4224... SUCCESS (retries: 0)
# [Processing] Dòng 4225... SUCCESS (retries: 0)
# [Processing] Dòng 4226... SUCCESS (retries: 0)
# [Processing] Dòng 4227... SUCCESS (retries: 0)
# [Processing] Dòng 4228... SUCCESS (retries: 0)
# [Processing] Dòng 4229... SUCCESS (retries: 3)
# [Processing] Dòng 4230... SUCCESS (retries: 0)
# [Processing] Dòng 4231... SUCCESS (retries: 0)
# [Processing] Dòng 4232... SUCCESS (retries: 0)
# [Processing] Dòng 4233... SUCCESS (retries: 0)
# [Processing] Dòng 4234... SUCCESS (retries: 0)
# [Processing] Dòng 4235... SUCCESS (retries: 0)
# [Processing] Dòng 4236... SUCCESS (retries: 0)
# [Processing] Dòng 4237... SUCCESS (retries: 3)
# [Processing] Dòng 4238... SUCCESS (retries: 0)
# [Processing] Dòng 4239... SUCCESS (retries: 0)
# [Processing] Dòng 4240... SUCCESS (retries: 0)
# [Processing] Dòng 4241... SUCCESS (retries: 0)
# [Processing] Dòng 4242... SUCCESS (retries: 0)
# [Processing] Dòng 4243... SUCCESS (retries: 0)
# [Processing] Dòng 4244... SUCCESS (retries: 0)
# [Processing] Dòng 4245... SUCCESS (retries: 0)
# [Processing] Dòng 4246... SUCCESS (retries: 0)
# [Processing] Dòng 4247... SUCCESS (retries: 0)
# [Processing] Dòng 4248... SUCCESS (retries: 0)
# [Processing] Dòng 4249... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
# [Processing] Dòng 4250... SUCCESS (retries: 0)
# [Processing] Dòng 4251... SUCCESS (retries: 0)
# [Processing] Dòng 4252... SUCCESS (retries: 3)
# [Processing] Dòng 4253... SUCCESS (retries: 0)
# [Processing] Dòng 4254... SUCCESS (retries: 0)
# [Processing] Dòng 4255... SUCCESS (retries: 0)
# [Processing] Dòng 4256... SUCCESS (retries: 0)
# [Processing] Dòng 4257... SUCCESS (retries: 0)
# [Processing] Dòng 4258... SUCCESS (retries: 0)
# [Processing] Dòng 4259... SUCCESS (retries: 0)
# [Processing] Dòng 4260... SUCCESS (retries: 0)
# [Processing] Dòng 4261... SUCCESS (retries: 0)
# [Processing] Dòng 4262... SUCCESS (retries: 0)
# [Processing] Dòng 4263... SUCCESS (retries: 0)
# [Processing] Dòng 4264... SUCCESS (retries: 0)
# [Processing] Dòng 4265... SUCCESS (retries: 0)
# [Processing] Dòng 4266... SUCCESS (retries: 2)
# [Processing] Dòng 4267... SUCCESS (retries: 0)
# [Processing] Dòng 4268... SUCCESS (retries: 0)
# [Processing] Dòng 4269... SUCCESS (retries: 0)
# [Processing] Dòng 4270... SUCCESS (retries: 0)
# [Processing] Dòng 4271... SUCCESS (retries: 3)
# [Processing] Dòng 4272... SUCCESS (retries: 0)
# [Processing] Dòng 4273... SUCCESS (retries: 0)
# [Processing] Dòng 4274... SUCCESS (retries: 0)
# [Processing] Dòng 4275... SUCCESS (retries: 0)
# [Processing] Dòng 4276... SUCCESS (retries: 0)
# [Processing] Dòng 4277... SUCCESS (retries: 0)
# [Processing] Dòng 4278... SUCCESS (retries: 2)
# [Processing] Dòng 4279... SUCCESS (retries: 0)
# [Processing] Dòng 4280... SUCCESS (retries: 0)
# [Processing] Dòng 4281... SUCCESS (retries: 0)
# [Processing] Dòng 4282... SUCCESS (retries: 0)
# [Processing] Dòng 4283... SUCCESS (retries: 0)
# [Processing] Dòng 4284... SUCCESS (retries: 0)
# [Processing] Dòng 4285... SUCCESS (retries: 0)
# [Processing] Dòng 4286... SUCCESS (retries: 0)
# [Processing] Dòng 4287... SUCCESS (retries: 0)
# [Processing] Dòng 4288... SUCCESS (retries: 0)
# [Processing] Dòng 4289... SUCCESS (retries: 0)
# [Processing] Dòng 4290... SUCCESS (retries: 0)
# [Processing] Dòng 4291... SUCCESS (retries: 0)
# [Processing] Dòng 4292... SUCCESS (retries: 0)
# [Processing] Dòng 4293... SUCCESS (retries: 3)
# [Processing] Dòng 4294... SUCCESS (retries: 1)
# [Processing] Dòng 4295... SUCCESS (retries: 0)
# [Processing] Dòng 4296... SUCCESS (retries: 0)
# [Processing] Dòng 4297... SUCCESS (retries: 0)
# [Processing] Dòng 4298... SUCCESS (retries: 0)
# [Processing] Dòng 4299... SUCCESS (retries: 1)
# [CHECKPOINT] Đã lưu sau 50 dòng
#
# ================================================================================
# [LOG] Dòng 4200-4299
# ================================================================================
# Thành công:     100
# Error:          0
# Timeout Error:  0
# Tổng xử lý:     100
# Tiến độ:        4300/4833 (88.97%)
# Thời gian:      80.65 phút
# Ước tính còn:   10.00 phút
# ================================================================================
#
# [Processing] Dòng 4300... SUCCESS (retries: 0)
# [Processing] Dòng 4301... SUCCESS (retries: 0)
# [Processing] Dòng 4302... SUCCESS (retries: 0)
# [Processing] Dòng 4303... SUCCESS (retries: 0)
# [Processing] Dòng 4304... SUCCESS (retries: 0)
# [Processing] Dòng 4305... SUCCESS (retries: 0)
# [Processing] Dòng 4306... SUCCESS (retries: 3)
# [Processing] Dòng 4307... SUCCESS (retries: 0)
# [Processing] Dòng 4308... SUCCESS (retries: 0)
# [Processing] Dòng 4309... SUCCESS (retries: 0)
# [Processing] Dòng 4310... SUCCESS (retries: 0)
# [Processing] Dòng 4311... SUCCESS (retries: 0)
# [Processing] Dòng 4312... SUCCESS (retries: 0)
# [Processing] Dòng 4313... SUCCESS (retries: 0)
# [Processing] Dòng 4314... SUCCESS (retries: 0)
# [Processing] Dòng 4315... SUCCESS (retries: 0)
# [Processing] Dòng 4316... SUCCESS (retries: 0)
# [Processing] Dòng 4317... SUCCESS (retries: 0)
# [Processing] Dòng 4318... SUCCESS (retries: 0)
# [Processing] Dòng 4319... SUCCESS (retries: 0)
# [Processing] Dòng 4320... SUCCESS (retries: 0)
# [Processing] Dòng 4321... SUCCESS (retries: 0)
# [Processing] Dòng 4322... SUCCESS (retries: 3)
# [Processing] Dòng 4323... SUCCESS (retries: 0)
# [Processing] Dòng 4324... SUCCESS (retries: 0)
# [Processing] Dòng 4325... SUCCESS (retries: 0)
# [Processing] Dòng 4326... SUCCESS (retries: 3)
# [Processing] Dòng 4327... SUCCESS (retries: 1)
# [Processing] Dòng 4328... SUCCESS (retries: 2)
# [Processing] Dòng 4329... SUCCESS (retries: 0)
# [Processing] Dòng 4330... SUCCESS (retries: 0)
# [Processing] Dòng 4331... SUCCESS (retries: 0)
# [Processing] Dòng 4332... SUCCESS (retries: 0)
# [Processing] Dòng 4333... SUCCESS (retries: 0)
# [Processing] Dòng 4334... SUCCESS (retries: 0)
# [Processing] Dòng 4335... SUCCESS (retries: 0)
# [Processing] Dòng 4336... SUCCESS (retries: 0)
# [Processing] Dòng 4337... SUCCESS (retries: 0)
# [Processing] Dòng 4338... SUCCESS (retries: 0)
# [Processing] Dòng 4339... SUCCESS (retries: 0)
# [Processing] Dòng 4340... SUCCESS (retries: 0)
# [Processing] Dòng 4341... SUCCESS (retries: 0)
# [Processing] Dòng 4342... SUCCESS (retries: 0)
# [Processing] Dòng 4343... SUCCESS (retries: 0)
# [Processing] Dòng 4344... SUCCESS (retries: 0)
# [Processing] Dòng 4345... SUCCESS (retries: 0)
# [Processing] Dòng 4346... SUCCESS (retries: 0)
# [Processing] Dòng 4347... SUCCESS (retries: 0)
# [Processing] Dòng 4348... SUCCESS (retries: 0)
# [Processing] Dòng 4349... SUCCESS (retries: 3)
# [CHECKPOINT] Đã lưu sau 50 dòng
# [Processing] Dòng 4350... SUCCESS (retries: 0)
# [Processing] Dòng 4351... SUCCESS (retries: 0)
# [Processing] Dòng 4352... SUCCESS (retries: 0)
# [Processing] Dòng 4353... SUCCESS (retries: 0)
# [Processing] Dòng 4354... SUCCESS (retries: 0)
# [Processing] Dòng 4355... SUCCESS (retries: 0)
# [Processing] Dòng 4356... SUCCESS (retries: 0)
# [Processing] Dòng 4357... SUCCESS (retries: 0)
# [Processing] Dòng 4358... SUCCESS (retries: 0)
# [Processing] Dòng 4359... SUCCESS (retries: 0)
# [Processing] Dòng 4360... SUCCESS (retries: 0)
# [Processing] Dòng 4361... SUCCESS (retries: 0)
# [Processing] Dòng 4362... SUCCESS (retries: 0)
# [Processing] Dòng 4363... SUCCESS (retries: 0)
# [Processing] Dòng 4364... SUCCESS (retries: 0)
# [Processing] Dòng 4365... SUCCESS (retries: 0)
# [Processing] Dòng 4366... SUCCESS (retries: 0)
# [Processing] Dòng 4367... SUCCESS (retries: 0)
# [Processing] Dòng 4368... SUCCESS (retries: 0)
# [Processing] Dòng 4369... SUCCESS (retries: 0)
# [Processing] Dòng 4370... SUCCESS (retries: 0)
# [Processing] Dòng 4371... SUCCESS (retries: 0)
# [Processing] Dòng 4372... SUCCESS (retries: 0)
# [Processing] Dòng 4373... SUCCESS (retries: 0)
# [Processing] Dòng 4374... SUCCESS (retries: 0)
# [Processing] Dòng 4375... SUCCESS (retries: 0)
# [Processing] Dòng 4376... SUCCESS (retries: 0)
# [Processing] Dòng 4377... SUCCESS (retries: 0)
# [Processing] Dòng 4378... SUCCESS (retries: 0)
# [Processing] Dòng 4379... SUCCESS (retries: 0)
# [Processing] Dòng 4380... SUCCESS (retries: 0)
# [Processing] Dòng 4381... SUCCESS (retries: 0)
# [Processing] Dòng 4382... SUCCESS (retries: 0)
# [Processing] Dòng 4383... SUCCESS (retries: 0)
# [Processing] Dòng 4384... SUCCESS (retries: 0)
# [Processing] Dòng 4385... SUCCESS (retries: 0)
# [Processing] Dòng 4386... SUCCESS (retries: 0)
# [Processing] Dòng 4387... SUCCESS (retries: 0)
# [Processing] Dòng 4388... SUCCESS (retries: 0)
# [Processing] Dòng 4389... SUCCESS (retries: 0)
# [Processing] Dòng 4390... SUCCESS (retries: 0)
# [Processing] Dòng 4391... SUCCESS (retries: 0)
# [Processing] Dòng 4392... SUCCESS (retries: 0)
# [Processing] Dòng 4393... SUCCESS (retries: 0)
# [Processing] Dòng 4394... SUCCESS (retries: 0)
# [Processing] Dòng 4395... SUCCESS (retries: 0)
# [Processing] Dòng 4396... SUCCESS (retries: 0)
# [Processing] Dòng 4397... SUCCESS (retries: 0)
# [Processing] Dòng 4398... SUCCESS (retries: 0)
# [Processing] Dòng 4399... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
#
# ================================================================================
# [LOG] Dòng 4300-4399
# ================================================================================
# Thành công:     100
# Error:          0
# Timeout Error:  0
# Tổng xử lý:     100
# Tiến độ:        4400/4833 (91.04%)
# Thời gian:      114.70 phút
# Ước tính còn:   11.29 phút
# ================================================================================
#
# [Processing] Dòng 4400... SUCCESS (retries: 0)
# [Processing] Dòng 4401... SUCCESS (retries: 0)
# [Processing] Dòng 4402... SUCCESS (retries: 0)
# [Processing] Dòng 4403... SUCCESS (retries: 0)
# [Processing] Dòng 4404... SUCCESS (retries: 0)
# [Processing] Dòng 4405... SUCCESS (retries: 0)
# [Processing] Dòng 4406... SUCCESS (retries: 0)
# [Processing] Dòng 4407... SUCCESS (retries: 0)
# [Processing] Dòng 4408... SUCCESS (retries: 0)
# [Processing] Dòng 4409... SUCCESS (retries: 0)
# [Processing] Dòng 4410... SUCCESS (retries: 0)
# [Processing] Dòng 4411... SUCCESS (retries: 0)
# [Processing] Dòng 4412... SUCCESS (retries: 0)
# [Processing] Dòng 4413... SUCCESS (retries: 0)
# [Processing] Dòng 4414... SUCCESS (retries: 0)
# [Processing] Dòng 4415... SUCCESS (retries: 0)
# [Processing] Dòng 4416... SUCCESS (retries: 0)
# [Processing] Dòng 4417... SUCCESS (retries: 0)
# [Processing] Dòng 4418... SUCCESS (retries: 0)
# [Processing] Dòng 4419... SUCCESS (retries: 0)
# [Processing] Dòng 4420... SUCCESS (retries: 0)
# [Processing] Dòng 4421... SUCCESS (retries: 0)
# [Processing] Dòng 4422... SUCCESS (retries: 0)
# [Processing] Dòng 4423... SUCCESS (retries: 3)
# [Processing] Dòng 4424... SUCCESS (retries: 0)
# [Processing] Dòng 4425... SUCCESS (retries: 0)
# [Processing] Dòng 4426... SUCCESS (retries: 0)
# [Processing] Dòng 4427... SUCCESS (retries: 0)
# [Processing] Dòng 4428... SUCCESS (retries: 0)
# [Processing] Dòng 4429... SUCCESS (retries: 0)
# [Processing] Dòng 4430... SUCCESS (retries: 0)
# [Processing] Dòng 4431... SUCCESS (retries: 0)
# [Processing] Dòng 4432... SUCCESS (retries: 0)
# [Processing] Dòng 4433... SUCCESS (retries: 0)
# [Processing] Dòng 4434... SUCCESS (retries: 0)
# [Processing] Dòng 4435... SUCCESS (retries: 0)
# [Processing] Dòng 4436... SUCCESS (retries: 0)
# [Processing] Dòng 4437... SUCCESS (retries: 0)
# [Processing] Dòng 4438... SUCCESS (retries: 0)
# [Processing] Dòng 4439... SUCCESS (retries: 0)
# [Processing] Dòng 4440... SUCCESS (retries: 0)
# [Processing] Dòng 4441... SUCCESS (retries: 0)
# [Processing] Dòng 4442... SUCCESS (retries: 0)
# [Processing] Dòng 4443... SUCCESS (retries: 0)
# [Processing] Dòng 4444... SUCCESS (retries: 0)
# [Processing] Dòng 4445... SUCCESS (retries: 0)
# [Processing] Dòng 4446... SUCCESS (retries: 0)
# [Processing] Dòng 4447... SUCCESS (retries: 0)
# [Processing] Dòng 4448... SUCCESS (retries: 0)
# [Processing] Dòng 4449... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
# [Processing] Dòng 4450... SUCCESS (retries: 0)
# [Processing] Dòng 4451... SUCCESS (retries: 0)
# [Processing] Dòng 4452... SUCCESS (retries: 0)
# [Processing] Dòng 4453... SUCCESS (retries: 0)
# [Processing] Dòng 4454... SUCCESS (retries: 0)
# [Processing] Dòng 4455... SUCCESS (retries: 0)
# [Processing] Dòng 4456... SUCCESS (retries: 0)
# [Processing] Dòng 4457... SUCCESS (retries: 0)
# [Processing] Dòng 4458... SUCCESS (retries: 0)
# [Processing] Dòng 4459... SUCCESS (retries: 0)
# [Processing] Dòng 4460... SUCCESS (retries: 0)
# [Processing] Dòng 4461... SUCCESS (retries: 0)
# [Processing] Dòng 4462... SUCCESS (retries: 0)
# [Processing] Dòng 4463... SUCCESS (retries: 0)
# [Processing] Dòng 4464... SUCCESS (retries: 0)
# [Processing] Dòng 4465... SUCCESS (retries: 0)
# [Processing] Dòng 4466... SUCCESS (retries: 0)
# [Processing] Dòng 4467... SUCCESS (retries: 0)
# [Processing] Dòng 4468... SUCCESS (retries: 0)
# [Processing] Dòng 4469... SUCCESS (retries: 0)
# [Processing] Dòng 4470... SUCCESS (retries: 0)
# [Processing] Dòng 4471... SUCCESS (retries: 0)
# [Processing] Dòng 4472... SUCCESS (retries: 0)
# [Processing] Dòng 4473... SUCCESS (retries: 0)
# [Processing] Dòng 4474... SUCCESS (retries: 0)
# [Processing] Dòng 4475... SUCCESS (retries: 0)
# [Processing] Dòng 4476... SUCCESS (retries: 0)
# [Processing] Dòng 4477... SUCCESS (retries: 3)
# [Processing] Dòng 4478... SUCCESS (retries: 0)
# [Processing] Dòng 4479... SUCCESS (retries: 0)
# [Processing] Dòng 4480... SUCCESS (retries: 0)
# [Processing] Dòng 4481... SUCCESS (retries: 0)
# [Processing] Dòng 4482... SUCCESS (retries: 0)
# [Processing] Dòng 4483... SUCCESS (retries: 0)
# [Processing] Dòng 4484... SUCCESS (retries: 0)
# [Processing] Dòng 4485... SUCCESS (retries: 0)
# [Processing] Dòng 4486... SUCCESS (retries: 0)
# [Processing] Dòng 4487... SUCCESS (retries: 0)
# [Processing] Dòng 4488... SUCCESS (retries: 0)
# [Processing] Dòng 4489... SUCCESS (retries: 0)
# [Processing] Dòng 4490... SUCCESS (retries: 0)
# [Processing] Dòng 4491... SUCCESS (retries: 0)
# [Processing] Dòng 4492... SUCCESS (retries: 0)
# [Processing] Dòng 4493... SUCCESS (retries: 0)
# [Processing] Dòng 4494... SUCCESS (retries: 0)
# [Processing] Dòng 4495... SUCCESS (retries: 0)
# [Processing] Dòng 4496... SUCCESS (retries: 0)
# [Processing] Dòng 4497... SUCCESS (retries: 0)
# [Processing] Dòng 4498... SUCCESS (retries: 0)
# [Processing] Dòng 4499... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
#
# ================================================================================
# [LOG] Dòng 4400-4499
# ================================================================================
# Thành công:     100
# Error:          0
# Timeout Error:  0
# Tổng xử lý:     100
# Tiến độ:        4500/4833 (93.11%)
# Thời gian:      146.21 phút
# Ước tính còn:   10.82 phút
# ================================================================================
#
# [Processing] Dòng 4500... SUCCESS (retries: 0)
# [Processing] Dòng 4501... SUCCESS (retries: 0)
# [Processing] Dòng 4502... SUCCESS (retries: 0)
# [Processing] Dòng 4503... SUCCESS (retries: 0)
# [Processing] Dòng 4504... SUCCESS (retries: 0)
# [Processing] Dòng 4505... SUCCESS (retries: 0)
# [Processing] Dòng 4506... SUCCESS (retries: 0)
# [Processing] Dòng 4507... SUCCESS (retries: 0)
# [Processing] Dòng 4508... SUCCESS (retries: 0)
# [Processing] Dòng 4509... SUCCESS (retries: 0)
# [Processing] Dòng 4510... SUCCESS (retries: 3)
# [Processing] Dòng 4511... SUCCESS (retries: 3)
# [Processing] Dòng 4512... SUCCESS (retries: 0)
# [Processing] Dòng 4513... SUCCESS (retries: 0)
# [Processing] Dòng 4514... SUCCESS (retries: 0)
# [Processing] Dòng 4515... SUCCESS (retries: 0)
# [Processing] Dòng 4516... SUCCESS (retries: 0)
# [Processing] Dòng 4517... SUCCESS (retries: 0)
# [Processing] Dòng 4518... SUCCESS (retries: 0)
# [Processing] Dòng 4519... SUCCESS (retries: 0)
# [Processing] Dòng 4520... SUCCESS (retries: 0)
# [Processing] Dòng 4521... SUCCESS (retries: 0)
# [Processing] Dòng 4522... SUCCESS (retries: 0)
# [Processing] Dòng 4523... SUCCESS (retries: 0)
# [Processing] Dòng 4524... SUCCESS (retries: 0)
# [Processing] Dòng 4525... SUCCESS (retries: 0)
# [Processing] Dòng 4526... SUCCESS (retries: 0)
# [Processing] Dòng 4527... SUCCESS (retries: 0)
# [Processing] Dòng 4528... SUCCESS (retries: 0)
# [Processing] Dòng 4529... SUCCESS (retries: 0)
# [Processing] Dòng 4530... SUCCESS (retries: 0)
# [Processing] Dòng 4531... SUCCESS (retries: 0)
# [Processing] Dòng 4532... SUCCESS (retries: 0)
# [Processing] Dòng 4533... SUCCESS (retries: 0)
# [Processing] Dòng 4534... SUCCESS (retries: 0)
# [Processing] Dòng 4535... SUCCESS (retries: 0)
# [Processing] Dòng 4536... SUCCESS (retries: 0)
# [Processing] Dòng 4537... SUCCESS (retries: 0)
# [Processing] Dòng 4538... SUCCESS (retries: 0)
# [Processing] Dòng 4539... SUCCESS (retries: 0)
# [Processing] Dòng 4540... SUCCESS (retries: 0)
# [Processing] Dòng 4541... SUCCESS (retries: 0)
# [Processing] Dòng 4542... SUCCESS (retries: 0)
# [Processing] Dòng 4543... SUCCESS (retries: 0)
# [Processing] Dòng 4544... SUCCESS (retries: 0)
# [Processing] Dòng 4545... SUCCESS (retries: 0)
# [Processing] Dòng 4546... SUCCESS (retries: 0)
# [Processing] Dòng 4547... SUCCESS (retries: 0)
# [Processing] Dòng 4548... SUCCESS (retries: 0)
# [Processing] Dòng 4549... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
# [Processing] Dòng 4550... SUCCESS (retries: 0)
# [Processing] Dòng 4551... SUCCESS (retries: 0)
# [Processing] Dòng 4552... SUCCESS (retries: 0)
# [Processing] Dòng 4553... SUCCESS (retries: 0)
# [Processing] Dòng 4554... SUCCESS (retries: 0)
# [Processing] Dòng 4555... SUCCESS (retries: 0)
# [Processing] Dòng 4556... SUCCESS (retries: 0)
# [Processing] Dòng 4557... SUCCESS (retries: 0)
# [Processing] Dòng 4558... SUCCESS (retries: 0)
# [Processing] Dòng 4559... SUCCESS (retries: 0)
# [Processing] Dòng 4560... SUCCESS (retries: 0)
# [Processing] Dòng 4561... SUCCESS (retries: 0)
# [Processing] Dòng 4562... SUCCESS (retries: 0)
# [Processing] Dòng 4563... SUCCESS (retries: 0)
# [Processing] Dòng 4564... SUCCESS (retries: 0)
# [Processing] Dòng 4565... SUCCESS (retries: 0)
# [Processing] Dòng 4566... SUCCESS (retries: 0)
# [Processing] Dòng 4567... SUCCESS (retries: 0)
# [Processing] Dòng 4568... SUCCESS (retries: 0)
# [Processing] Dòng 4569... SUCCESS (retries: 0)
# [Processing] Dòng 4570... SUCCESS (retries: 0)
# [Processing] Dòng 4571... SUCCESS (retries: 0)
# [Processing] Dòng 4572... SUCCESS (retries: 0)
# [Processing] Dòng 4573... SUCCESS (retries: 0)
# [Processing] Dòng 4574... SUCCESS (retries: 0)
# [Processing] Dòng 4575... SUCCESS (retries: 0)
# [Processing] Dòng 4576... SUCCESS (retries: 0)
# [Processing] Dòng 4577... SUCCESS (retries: 0)
# [Processing] Dòng 4578... SUCCESS (retries: 0)
# [Processing] Dòng 4579... SUCCESS (retries: 0)
# [Processing] Dòng 4580... SUCCESS (retries: 0)
# [Processing] Dòng 4581... SUCCESS (retries: 0)
# [Processing] Dòng 4582... SUCCESS (retries: 0)
# [Processing] Dòng 4583... SUCCESS (retries: 0)
# [Processing] Dòng 4584... SUCCESS (retries: 0)
# [Processing] Dòng 4585... SUCCESS (retries: 0)
# [Processing] Dòng 4586... SUCCESS (retries: 0)
# [Processing] Dòng 4587... SUCCESS (retries: 0)
# [Processing] Dòng 4588... SUCCESS (retries: 0)
# [Processing] Dòng 4589... SUCCESS (retries: 0)
# [Processing] Dòng 4590... SUCCESS (retries: 0)
# [Processing] Dòng 4591... SUCCESS (retries: 0)
# [Processing] Dòng 4592... SUCCESS (retries: 0)
# [Processing] Dòng 4593... SUCCESS (retries: 0)
# [Processing] Dòng 4594... SUCCESS (retries: 0)
# [Processing] Dòng 4595... SUCCESS (retries: 0)
# [Processing] Dòng 4596... SUCCESS (retries: 0)
# [Processing] Dòng 4597... SUCCESS (retries: 0)
# [Processing] Dòng 4598... SUCCESS (retries: 0)
# [Processing] Dòng 4599... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
#
# ================================================================================
# [LOG] Dòng 4500-4599
# ================================================================================
# Thành công:     100
# Error:          0
# Timeout Error:  0
# Tổng xử lý:     100
# Tiến độ:        4600/4833 (95.18%)
# Thời gian:      176.62 phút
# Ước tính còn:   8.95 phút
# ================================================================================
#
# [Processing] Dòng 4600... SUCCESS (retries: 0)
# [Processing] Dòng 4601... SUCCESS (retries: 0)
# [Processing] Dòng 4602... SUCCESS (retries: 0)
# [Processing] Dòng 4603... SUCCESS (retries: 3)
# [Processing] Dòng 4604... SUCCESS (retries: 0)
# [Processing] Dòng 4605... SUCCESS (retries: 0)
# [Processing] Dòng 4606... SUCCESS (retries: 0)
# [Processing] Dòng 4607... SUCCESS (retries: 0)
# [Processing] Dòng 4608... SUCCESS (retries: 0)
# [Processing] Dòng 4609... SUCCESS (retries: 0)
# [Processing] Dòng 4610... SUCCESS (retries: 0)
# [Processing] Dòng 4611... SUCCESS (retries: 0)
# [Processing] Dòng 4612... SUCCESS (retries: 0)
# [Processing] Dòng 4613... SUCCESS (retries: 0)
# [Processing] Dòng 4614... SUCCESS (retries: 0)
# [Processing] Dòng 4615... SUCCESS (retries: 0)
# [Processing] Dòng 4616... SUCCESS (retries: 0)
# [Processing] Dòng 4617... SUCCESS (retries: 0)
# [Processing] Dòng 4618... SUCCESS (retries: 0)
# [Processing] Dòng 4619... SUCCESS (retries: 0)
# [Processing] Dòng 4620... SUCCESS (retries: 0)
# [Processing] Dòng 4621... SUCCESS (retries: 0)
# [Processing] Dòng 4622... SUCCESS (retries: 0)
# [Processing] Dòng 4623... SUCCESS (retries: 0)
# [Processing] Dòng 4624... SUCCESS (retries: 0)
# [Processing] Dòng 4625... SUCCESS (retries: 0)
# [Processing] Dòng 4626... SUCCESS (retries: 0)
# [Processing] Dòng 4627... SUCCESS (retries: 0)
# [Processing] Dòng 4628... SUCCESS (retries: 0)
# [Processing] Dòng 4629... SUCCESS (retries: 0)
# [Processing] Dòng 4630... SUCCESS (retries: 0)
# [Processing] Dòng 4631... SUCCESS (retries: 0)
# [Processing] Dòng 4632... SUCCESS (retries: 0)
# [Processing] Dòng 4633... SUCCESS (retries: 0)
# [Processing] Dòng 4634... SUCCESS (retries: 0)
# [Processing] Dòng 4635... SUCCESS (retries: 0)
# [Processing] Dòng 4636... SUCCESS (retries: 0)
# [Processing] Dòng 4637... SUCCESS (retries: 0)
# [Processing] Dòng 4638... SUCCESS (retries: 0)
# [Processing] Dòng 4639... SUCCESS (retries: 0)
# [Processing] Dòng 4640... SUCCESS (retries: 0)
# [Processing] Dòng 4641... SUCCESS (retries: 0)
# [Processing] Dòng 4642... SUCCESS (retries: 0)
# [Processing] Dòng 4643... SUCCESS (retries: 0)
# [Processing] Dòng 4644... SUCCESS (retries: 0)
# [Processing] Dòng 4645... SUCCESS (retries: 0)
# [Processing] Dòng 4646... SUCCESS (retries: 0)
# [Processing] Dòng 4647... SUCCESS (retries: 0)
# [Processing] Dòng 4648... SUCCESS (retries: 0)
# [Processing] Dòng 4649... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
# [Processing] Dòng 4650... SUCCESS (retries: 0)
# [Processing] Dòng 4651... SUCCESS (retries: 0)
# [Processing] Dòng 4652... SUCCESS (retries: 0)
# [Processing] Dòng 4653... SUCCESS (retries: 0)
# [Processing] Dòng 4654... SUCCESS (retries: 0)
# [Processing] Dòng 4655... SUCCESS (retries: 0)
# [Processing] Dòng 4656... SUCCESS (retries: 3)
# [Processing] Dòng 4657... SUCCESS (retries: 0)
# [Processing] Dòng 4658... SUCCESS (retries: 0)
# [Processing] Dòng 4659... SUCCESS (retries: 0)
# [Processing] Dòng 4660... SUCCESS (retries: 0)
# [Processing] Dòng 4661... SUCCESS (retries: 0)
# [Processing] Dòng 4662... SUCCESS (retries: 0)
# [Processing] Dòng 4663... SUCCESS (retries: 0)
# [Processing] Dòng 4664... SUCCESS (retries: 0)
# [Processing] Dòng 4665... SUCCESS (retries: 3)
# [Processing] Dòng 4666... SUCCESS (retries: 0)
# [Processing] Dòng 4667... SUCCESS (retries: 0)
# [Processing] Dòng 4668... SUCCESS (retries: 0)
# [Processing] Dòng 4669... SUCCESS (retries: 0)
# [Processing] Dòng 4670... SUCCESS (retries: 0)
# [Processing] Dòng 4671... SUCCESS (retries: 0)
# [Processing] Dòng 4672... SUCCESS (retries: 0)
# [Processing] Dòng 4673... SUCCESS (retries: 0)
# [Processing] Dòng 4674... SUCCESS (retries: 0)
# [Processing] Dòng 4675... SUCCESS (retries: 0)
# [Processing] Dòng 4676... SUCCESS (retries: 1)
# [Processing] Dòng 4677... SUCCESS (retries: 0)
# [Processing] Dòng 4678... SUCCESS (retries: 0)
# [Processing] Dòng 4679... SUCCESS (retries: 0)
# [Processing] Dòng 4680... SUCCESS (retries: 0)
# [Processing] Dòng 4681... SUCCESS (retries: 0)
# [Processing] Dòng 4682... SUCCESS (retries: 0)
# [Processing] Dòng 4683... SUCCESS (retries: 0)
# [Processing] Dòng 4684... SUCCESS (retries: 0)
# [Processing] Dòng 4685... SUCCESS (retries: 0)
# [Processing] Dòng 4686... SUCCESS (retries: 0)
# [Processing] Dòng 4687... SUCCESS (retries: 0)
# [Processing] Dòng 4688... SUCCESS (retries: 0)
# [Processing] Dòng 4689... SUCCESS (retries: 0)
# [Processing] Dòng 4690... SUCCESS (retries: 0)
# [Processing] Dòng 4691... SUCCESS (retries: 0)
# [Processing] Dòng 4692... SUCCESS (retries: 0)
# [Processing] Dòng 4693... SUCCESS (retries: 0)
# [Processing] Dòng 4694... SUCCESS (retries: 0)
# [Processing] Dòng 4695... SUCCESS (retries: 0)
# [Processing] Dòng 4696... SUCCESS (retries: 0)
# [Processing] Dòng 4697... SUCCESS (retries: 0)
# [Processing] Dòng 4698... SUCCESS (retries: 0)
# [Processing] Dòng 4699... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
#
# ================================================================================
# [LOG] Dòng 4600-4699
# ================================================================================
# Thành công:     100
# Error:          0
# Timeout Error:  0
# Tổng xử lý:     100
# Tiến độ:        4700/4833 (97.25%)
# Thời gian:      207.97 phút
# Ước tính còn:   5.88 phút
# ================================================================================
#
# [Processing] Dòng 4700... SUCCESS (retries: 0)
# [Processing] Dòng 4701... SUCCESS (retries: 0)
# [Processing] Dòng 4702... SUCCESS (retries: 0)
# [Processing] Dòng 4703... SUCCESS (retries: 0)
# [Processing] Dòng 4704... SUCCESS (retries: 0)
# [Processing] Dòng 4705... SUCCESS (retries: 0)
# [Processing] Dòng 4706... SUCCESS (retries: 0)
# [Processing] Dòng 4707... SUCCESS (retries: 0)
# [Processing] Dòng 4708... SUCCESS (retries: 0)
# [Processing] Dòng 4709... SUCCESS (retries: 0)
# [Processing] Dòng 4710... SUCCESS (retries: 0)
# [Processing] Dòng 4711... SUCCESS (retries: 0)
# [Processing] Dòng 4712... SUCCESS (retries: 0)
# [Processing] Dòng 4713... SUCCESS (retries: 0)
# [Processing] Dòng 4714... SUCCESS (retries: 0)
# [Processing] Dòng 4715... SUCCESS (retries: 0)
# [Processing] Dòng 4716... SUCCESS (retries: 0)
# [Processing] Dòng 4717... SUCCESS (retries: 0)
# [Processing] Dòng 4718... SUCCESS (retries: 0)
# [Processing] Dòng 4719... SUCCESS (retries: 0)
# [Processing] Dòng 4720... SUCCESS (retries: 0)
# [Processing] Dòng 4721... SUCCESS (retries: 0)
# [Processing] Dòng 4722... SUCCESS (retries: 0)
# [Processing] Dòng 4723... SUCCESS (retries: 0)
# [Processing] Dòng 4724... SUCCESS (retries: 2)
# [Processing] Dòng 4725... SUCCESS (retries: 0)
# [Processing] Dòng 4726... SUCCESS (retries: 0)
# [Processing] Dòng 4727... SUCCESS (retries: 0)
# [Processing] Dòng 4728... SUCCESS (retries: 0)
# [Processing] Dòng 4729... SUCCESS (retries: 0)
# [Processing] Dòng 4730... SUCCESS (retries: 0)
# [Processing] Dòng 4731... SUCCESS (retries: 0)
# [Processing] Dòng 4732... SUCCESS (retries: 0)
# [Processing] Dòng 4733... SUCCESS (retries: 0)
# [Processing] Dòng 4734... SUCCESS (retries: 0)
# [Processing] Dòng 4735... SUCCESS (retries: 0)
# [Processing] Dòng 4736... SUCCESS (retries: 0)
# [Processing] Dòng 4737... SUCCESS (retries: 0)
# [Processing] Dòng 4738... SUCCESS (retries: 0)
# [Processing] Dòng 4739... SUCCESS (retries: 0)
# [Processing] Dòng 4740... SUCCESS (retries: 0)
# [Processing] Dòng 4741... SUCCESS (retries: 0)
# [Processing] Dòng 4742... SUCCESS (retries: 0)
# [Processing] Dòng 4743... SUCCESS (retries: 0)
# [Processing] Dòng 4744... SUCCESS (retries: 0)
# [Processing] Dòng 4745... SUCCESS (retries: 0)
# [Processing] Dòng 4746... SUCCESS (retries: 0)
# [Processing] Dòng 4747... SUCCESS (retries: 0)
# [Processing] Dòng 4748... SUCCESS (retries: 0)
# [Processing] Dòng 4749... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
# [Processing] Dòng 4750... SUCCESS (retries: 0)
# [Processing] Dòng 4751... SUCCESS (retries: 0)
# [Processing] Dòng 4752... SUCCESS (retries: 0)
# [Processing] Dòng 4753... SUCCESS (retries: 0)
# [Processing] Dòng 4754... SUCCESS (retries: 0)
# [Processing] Dòng 4755... SUCCESS (retries: 0)
# [Processing] Dòng 4756... SUCCESS (retries: 0)
# [Processing] Dòng 4757... SUCCESS (retries: 0)
# [Processing] Dòng 4758... SUCCESS (retries: 0)
# [Processing] Dòng 4759... SUCCESS (retries: 0)
# [Processing] Dòng 4760... SUCCESS (retries: 0)
# [Processing] Dòng 4761... SUCCESS (retries: 0)
# [Processing] Dòng 4762... SUCCESS (retries: 0)
# [Processing] Dòng 4763... SUCCESS (retries: 0)
# [Processing] Dòng 4764... SUCCESS (retries: 0)
# [Processing] Dòng 4765... SUCCESS (retries: 0)
# [Processing] Dòng 4766... SUCCESS (retries: 0)
# [Processing] Dòng 4767... SUCCESS (retries: 0)
# [Processing] Dòng 4768... SUCCESS (retries: 0)
# [Processing] Dòng 4769... SUCCESS (retries: 0)
# [Processing] Dòng 4770... SUCCESS (retries: 0)
# [Processing] Dòng 4771... SUCCESS (retries: 0)
# [Processing] Dòng 4772... SUCCESS (retries: 3)
# [Processing] Dòng 4773... SUCCESS (retries: 0)
# [Processing] Dòng 4774... SUCCESS (retries: 0)
# [Processing] Dòng 4775... SUCCESS (retries: 0)
# [Processing] Dòng 4776... SUCCESS (retries: 0)
# [Processing] Dòng 4777... SUCCESS (retries: 0)
# [Processing] Dòng 4778... SUCCESS (retries: 0)
# [Processing] Dòng 4779... SUCCESS (retries: 0)
# [Processing] Dòng 4780... SUCCESS (retries: 0)
# [Processing] Dòng 4781... SUCCESS (retries: 0)
# [Processing] Dòng 4782... SUCCESS (retries: 0)
# [Processing] Dòng 4783... SUCCESS (retries: 0)
# [Processing] Dòng 4784... SUCCESS (retries: 0)
# [Processing] Dòng 4785... SUCCESS (retries: 0)
# [Processing] Dòng 4786... SUCCESS (retries: 1)
# [Processing] Dòng 4787... SUCCESS (retries: 0)
# [Processing] Dòng 4788... SUCCESS (retries: 0)
# [Processing] Dòng 4789... SUCCESS (retries: 0)
# [Processing] Dòng 4790... SUCCESS (retries: 0)
# [Processing] Dòng 4791... SUCCESS (retries: 0)
# [Processing] Dòng 4792... SUCCESS (retries: 0)
# [Processing] Dòng 4793... SUCCESS (retries: 0)
# [Processing] Dòng 4794... SUCCESS (retries: 0)
# [Processing] Dòng 4795... SUCCESS (retries: 0)
# [Processing] Dòng 4796... SUCCESS (retries: 0)
# [Processing] Dòng 4797... SUCCESS (retries: 0)
# [Processing] Dòng 4798... SUCCESS (retries: 0)
# [Processing] Dòng 4799... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
#
# ================================================================================
# [LOG] Dòng 4700-4799
# ================================================================================
# Thành công:     100
# Error:          0
# Timeout Error:  0
# Tổng xử lý:     100
# Tiến độ:        4800/4833 (99.32%)
# Thời gian:      238.85 phút
# Ước tính còn:   1.64 phút
# ================================================================================
#
# [Processing] Dòng 4800... SUCCESS (retries: 0)
# [Processing] Dòng 4801... SUCCESS (retries: 0)
# [Processing] Dòng 4802... SUCCESS (retries: 0)
# [Processing] Dòng 4803... SUCCESS (retries: 0)
# [Processing] Dòng 4804... SUCCESS (retries: 0)
# [Processing] Dòng 4805... SUCCESS (retries: 0)
# [Processing] Dòng 4806... SUCCESS (retries: 0)
# [Processing] Dòng 4807... SUCCESS (retries: 0)
# [Processing] Dòng 4808... SUCCESS (retries: 0)
# [Processing] Dòng 4809... SUCCESS (retries: 0)
# [Processing] Dòng 4810... SUCCESS (retries: 3)
# [Processing] Dòng 4811... SUCCESS (retries: 0)
# [Processing] Dòng 4812... SUCCESS (retries: 0)
# [Processing] Dòng 4813... SUCCESS (retries: 0)
# [Processing] Dòng 4814... SUCCESS (retries: 0)
# [Processing] Dòng 4815... SUCCESS (retries: 0)
# [Processing] Dòng 4816... SUCCESS (retries: 0)
# [Processing] Dòng 4817... SUCCESS (retries: 0)
# [Processing] Dòng 4818... SUCCESS (retries: 0)
# [Processing] Dòng 4819... SUCCESS (retries: 0)
# [Processing] Dòng 4820... SUCCESS (retries: 0)
# [Processing] Dòng 4821... SUCCESS (retries: 0)
# [Processing] Dòng 4822... SUCCESS (retries: 0)
# [Processing] Dòng 4823... SUCCESS (retries: 0)
# [Processing] Dòng 4824... SUCCESS (retries: 3)
# [Processing] Dòng 4825... SUCCESS (retries: 0)
# [Processing] Dòng 4826... SUCCESS (retries: 0)
# [Processing] Dòng 4827... SUCCESS (retries: 0)
# [Processing] Dòng 4828... SUCCESS (retries: 0)
# [Processing] Dòng 4829... SUCCESS (retries: 0)
# [Processing] Dòng 4830... SUCCESS (retries: 0)
# [Processing] Dòng 4831... SUCCESS (retries: 0)
# [Processing] Dòng 4832... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu 33 dòng cuối cùng
#
# ================================================================================
# HOÀN THÀNH
# ================================================================================
# Tổng số dòng:        4833
# Thành công:          4833 (100.00%)
# Error:               0 (0.00%)
# Timeout Error:       0 (0.00%)
# Tổng thời gian:      249.65 phút
# Thời gian trung bình: 3.10 giây/dòng
# Kết quả đã lưu tại:  /content/drive/MyDrive/T2C_finetune_gemma/finetune_gemma.csv
# ================================================================================
