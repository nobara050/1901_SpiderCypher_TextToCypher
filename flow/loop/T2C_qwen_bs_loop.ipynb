# %%
# %%capture
# !pip install --no-cache-dir "unsloth==2025.11.2"
# !pip install accelerate bitsandbytes huggingface_hub transformers neo4j_graphrag neo4j func-timeout

# %% [markdown]
# **Nhập API The Hugging Face để sử dụng**

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# **Import thư viện**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from unsloth.chat_templates import get_chat_template
from unsloth import FastLanguageModel
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from neo4j_graphrag.schema import get_structured_schema
from func_timeout import func_timeout, FunctionTimedOut
from neo4j.exceptions import AuthError, Neo4jError
from neo4j import GraphDatabase
from datetime import datetime
import pandas as pd
import torch
import time
import os
import re

# %%
import logging
import warnings
logging.getLogger('neo4j').setLevel(logging.ERROR)
warnings.filterwarnings('ignore', category=FutureWarning)

# %% [markdown]
# **Load model**

# %%
model_name = "qwen" # Chọn "qwen" hoặc "llama3"
model_id = "unsloth/Qwen2.5-7B-Instruct"
max_seq_length = 4096
dtype = None
load_in_4bit = True  # Dùng 4bit để tiết kiệm VRAM

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = model_id,
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)

# Chế độ Inference (Tăng tốc độ lên 2x)
FastLanguageModel.for_inference(model)

# Setup chat template
tokenizer = get_chat_template(
    tokenizer,
    chat_template = "qwen-2.5",
    map_eos_token = True,
)
# Out:
# ==((====))==  Unsloth 2025.11.2: Fast Qwen2 patching. Transformers: 4.57.2.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.1+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.5.1
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.33.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.16G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/271 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]

# %% [markdown]
# **Load Data**

# %%
# Load test data
checkpoint_path = '/content/drive/MyDrive/T2C_qwen_bs_loop/qwen_bs_loop.csv'
test_path = '/content/drive/MyDrive/T2C_qwen_bs_loop/text2cypher_test.csv'
test_df = pd.read_csv(test_path, encoding="utf-8-sig")

print(f"Loaded test shape: {test_df.shape}")
# Out:
# Loaded test shape: (4833, 6)

# %%
URI = "neo4j+s://demo.neo4jlabs.com:7687"

# Danh sách alias
unique_aliases = test_df["database_reference_alias"].dropna().unique().tolist()
DATABASE_ALIASES = unique_aliases

# Lưu trữ drivers, schemas, examples theo alias
DRIVERS_BY_ALIAS = {}

# %%
def extract_alias(alias: str):
    """Extract username và password từ alias"""
    name = alias.replace("neo4jlabs_demo_db_", "")
    return name, name

def get_driver(alias):
    """Lấy driver đã tồn tại hoặc tạo mới"""
    if alias in DRIVERS_BY_ALIAS:
        return DRIVERS_BY_ALIAS[alias]
    user, pwd = extract_alias(alias)
    driver = GraphDatabase.driver(URI, auth=(user, pwd))
    DRIVERS_BY_ALIAS[alias] = driver
    return driver

def reset_driver(alias):
    """Reset driver khi gặp lỗi auth"""
    print(f"Resetting driver for alias: {alias}")
    if alias in DRIVERS_BY_ALIAS:
        try:
            DRIVERS_BY_ALIAS[alias].close()
        except Exception as e:
            print(f"Error closing driver: {e}")
        del DRIVERS_BY_ALIAS[alias]

    # Tạo lại driver mới
    return get_driver(alias)

# %% [markdown]
# **Prompt Text2Cypher**

# %%
def create_messages(question, schema):
    system_message = """Task: Generate a Cypher statement to query a graph database. Instructions: Use only the provided relationship types and properties in the schema. Do not use any other relationship types or properties that are not provided in the schema. Do not include any explanations or apologies in your responses. Do not respond to any questions that ask anything other than constructing a Cypher statement. Do not include any text except the generated Cypher statement."""

    user_content = f"""Generate Cypher statement to query a graph database. Use only the provided relationship types and properties in the schema.
 Schema: {schema}
 Question: {question}
 Cypher output:"""

    messages = [
        {"role": "system", "content": system_message},
        {"role": "user", "content": user_content}
    ]

    return messages

print("Message creation function loaded successfully")
# Out:
# Message creation function loaded successfully

# %% [markdown]
# **Hàm chuyển đổi Text2Cypher**

# %%
def generate_cypher_raw(question, schema, timeout):
    messages = create_messages(question, schema)

    def _generate():
        # Apply chat template và tokenize
        inputs = tokenizer.apply_chat_template(
            messages,
            tokenize=True,
            add_generation_prompt=True,
            return_tensors="pt",
        ).to(model.device)
        # Create attention mask (very important!)
        attention_mask = (inputs != tokenizer.pad_token_id).long()
        # Generate
        with torch.no_grad():
            outputs = model.generate(
                input_ids=inputs,
                attention_mask=attention_mask,
                max_new_tokens=256,
                temperature=0.1,
                do_sample=True,
                top_p=0.9,
                use_cache=True,
                pad_token_id=tokenizer.eos_token_id,
            )

        # Decode output (giữ special tokens)
        generated_text = tokenizer.decode(outputs[0], skip_special_tokens=False)
        return generated_text

    try:
        return func_timeout(timeout, _generate)
    except FunctionTimedOut:
        print(f"[TIMEOUT] Generation exceeded {timeout}s")
        return "time_error"
    except Exception as e:
        print(f"[ERROR] Generation failed: {e}")
        return "error"

# %% [markdown]
# **Hàm format câu cypher từ output**

# %%
MODEL_TOKENS = {
    "qwen": {"start": "<|im_start|>assistant", "end": "<|im_end|>", "special_tokens": ["<|im_end|>", "<|im_start|>", "<|eot_id|>", "<|start_header_id|>", "<|end_header_id|>", "<|endoftext|>"]},
    "llama3": {"start": "<|start_header_id|>assistant<|end_header_id|>", "end": "<|eot_id|>", "special_tokens": ["<s>", "</s>", "<pad>"]}
}

def extract_cypher(text, model_name):
    if text in ["time_error", "error"]:
        return text

    try:
        # Bước 1: Extract assistant content
        tokens = MODEL_TOKENS[model_name]
        if tokens["start"] in text:
            after_assistant = text.split(tokens["start"])[-1]
            if tokens["end"] in after_assistant:
                assistant_content = after_assistant.split(tokens["end"])[0].strip()
            else:
                assistant_content = after_assistant.strip()
        else:
            assistant_content = text.strip()

        # Bước 2: Extract code block đầu tiên (giữa ``` ```)
        match = re.search(r"```(.*?)```", assistant_content, re.DOTALL)
        if match:
            code_block = match.group(1).strip()
        else:
            code_block = assistant_content.strip()

        # Bước 3: Tìm "MATCH" và trích xuất Cypher từ đó
        code_block_lower = code_block.lower()
        match_index = code_block_lower.find("match")
        if match_index == -1:
            return "error"

        cypher = code_block[match_index:].strip()

        # Loại bỏ special tokens
        for token in tokens["special_tokens"]:
            cypher = cypher.replace(token, "")
        cypher = cypher.strip()

        return cypher
    except:
        return "error"

print("✓ extract_cypher loaded")
# Out:
# ✓ extract_cypher loaded

# %%
def generate_cypher(question, schema, timeout=300, model_name=model_name):

    # Generate raw output
    raw_output = generate_cypher_raw(question, schema, timeout)

    # Extract Cypher
    cypher = extract_cypher(raw_output, model_name)

    return cypher

print("✓ generate_cypher loaded")
# Out:
# ✓ generate_cypher loaded

# %% [markdown]
# **Prompt Self Correction**

# %%
def prompt_correction(schema_context, question, cypher_current, error):
    # System message - Expert introduction
    system_message = "You are an expert at fixing Cypher queries. Analyze the error carefully and fix the query."

    # AUTO-HINT MECHANISM - GENERAL INSTRUCTIONS WITH COT
    additional_hint = ""

    # Syntax Error
    if "syntax error" in error.lower() or "invalid syntax" in error.lower():
        additional_hint = """
CRITICAL: Syntax error detected. Follow these steps to fix:

Step 1 - ANALYZE the error message:
- Identify which keyword/token is causing the error
- Check the position (line, column) where error occurs
- Understand what the parser expected at that position

Step 2 - COMMON SYNTAX RULES in Cypher:
- WHERE clause MUST come BEFORE RETURN, never after RETURN
- If you need multiple conditions, combine them with AND/OR in the same WHERE clause
- WITH clause cannot be the last clause - must be followed by RETURN or another clause
- RETURN must be the final clause (unless using UNION or other set operations)
- Cypher does NOT support GROUP BY - use aggregation functions in WITH instead
- Pattern expressions in WHERE must use pattern comprehension: SIZE([(pattern) | var])

Step 3 - FIX the query:
- Move misplaced clauses to correct position
- Combine multiple WHERE clauses into one
- Add missing RETURN if query ends with WITH
- Remove unsupported SQL syntax (GROUP BY, HAVING, etc.)

Example of common mistakes:
WRONG: MATCH (n) WHERE condition1 RETURN n WHERE condition2
CORRECT: MATCH (n) WHERE condition1 AND condition2 RETURN n

WRONG: WITH n.property, COUNT(*) AS count
CORRECT: WITH n.property AS property, COUNT(*) AS count
"""

    # Unknown/Missing properties or labels
    elif "unknown" in error.lower() or "does not exist" in error.lower() or "not found" in error.lower():
        additional_hint = """
CRITICAL: Unknown label/property detected. Follow these steps to fix:

Step 1 - IDENTIFY what is missing:
- Check if you're using a label that doesn't exist
- Check if you're accessing a property that doesn't exist
- Verify the entity type: is it a node property or relationship property?

Step 2 - VERIFY against schema:
- Node properties are listed under "Nodes" section
- Relationship properties are listed under "Relationships" section
- Labels use colon syntax (:Label), properties use dot syntax (variable.property)

Step 3 - FIX the query:
- Use correct property name from schema
- Access property from correct entity (node vs relationship)
- Replace incorrect label syntax with property access

Example of common mistakes:
WRONG: MATCH (n) WHERE n:`propertyName` = value
CORRECT: MATCH (n) WHERE n.propertyName = value

WRONG: Using relationship variable for node property: AVG(rel.nodeProperty)
CORRECT: Using node variable for node property: AVG(node.nodeProperty)
"""

    # Expression/Aliasing error
    elif "must be aliased" in error.lower() or "alias" in error.lower():
        additional_hint = """
CRITICAL: Aliasing error detected. Follow these steps to fix:

Step 1 - UNDERSTAND aliasing rules:
- In WITH clause, expressions must be aliased using AS
- Property expressions cannot be used directly without aliasing
- Aggregation results must be aliased

Step 2 - TWO APPROACHES to fix:
Approach A - Alias each property:
  WITH node.prop1 AS prop1, node.prop2 AS prop2, AGG(...) AS result

Approach B - Use node variable:
  WITH node, AGG(...) AS result
  RETURN node.prop1, node.prop2, result

Step 3 - CHOOSE the simpler approach:
- If you need many properties: use Approach B (pass entire node)
- If you need few properties: use Approach A (alias each one)
"""

    # Pattern/Structure error
    elif "pattern" in error.lower() or "cannot conclude" in error.lower():
        additional_hint = """
CRITICAL: Query structure error detected. Follow these steps to fix:

Step 1 - CHECK query structure:
- Does the query end with a proper clause? (RETURN, CREATE, DELETE, etc.)
- Are pattern expressions used correctly?
- Is SIZE() used with pattern comprehension?

Step 2 - COMMON STRUCTURE RULES:
- Query MUST end with RETURN (or update clause)
- WITH ... ORDER BY ... LIMIT MUST be followed by RETURN
- Pattern in SIZE() needs comprehension: SIZE([(pattern) | var]) not SIZE((pattern))
- Pattern existence check: use EXISTS { (pattern) } in WHERE

Step 3 - FIX based on rule violated:
- Add RETURN clause if missing
- Wrap pattern in comprehension for SIZE()
- Change to EXISTS if only checking presence

Example of common mistakes:
WRONG: WITH node, COUNT(*) AS count ORDER BY count LIMIT 10
CORRECT: WITH node, COUNT(*) AS count ORDER BY count LIMIT 10 RETURN node, count

WRONG: WHERE SIZE((a)-[:REL]->(b)) > 5
CORRECT: WHERE SIZE([(a)-[:REL]->(b) | a]) > 5
"""

    # Build user content
    user_content = f"""Fix the following Cypher query based on the error message.

Schema:
{schema_context}

Original Question: {question}

Wrong Cypher Query:
{cypher_current}

Error Message:
{error}
"""

    # Add hint if available
    if additional_hint:
        user_content += f"\n{additional_hint}\n"

    user_content += "\nFollow the steps above to analyze and fix the query. Return ONLY the corrected Cypher statement, no explanations.\n\nCorrected Cypher output:"

    # Build messages with system and user roles
    messages = [
        {"role": "system", "content": system_message},
        {"role": "user", "content": user_content}
    ]

    return messages

print("✓ build_correction_prompt loaded")
# Out:
# ✓ build_correction_prompt loaded

# %% [markdown]
# **Neo4j Execution**

# %%
def execute_cypher(cypher_query, alias, timeout=180):
    if cypher_query in ["error", "time_error", None, ""]:
        return (False, "Invalid cypher query")

    driver = get_driver(alias)

    try:
        with driver.session() as session:
            # Chỉ execute query, KHÔNG consume result
            session.run(cypher_query, timeout=timeout)
            return (True, None)
    except Exception as e:
        error_msg = str(e)
        # Nếu lỗi authentication, reset driver
        if "authentication" in error_msg.lower() or "unauthorized" in error_msg.lower():
            reset_driver(alias)
        return (False, error_msg)

print("✓ execute_cypher loaded")
# Out:
# ✓ execute_cypher loaded

# %%
def explain_cypher(cypher_query, driver, timeout=180):
    if cypher_query in ["error", None, ""]:
        return (False, "Invalid cypher query")

    try:
        with driver.session() as session:
            explain_query = f"EXPLAIN {cypher_query}"
            session.run(explain_query, timeout=timeout)
            return (True, None)
    except Exception as e:
        return (False, str(e))

print("✓ explain_cypher loaded")
# Out:
# ✓ explain_cypher loaded

# %% [markdown]
# **Setup model Self Loop**

# %%
def llm_correct_cypher(schema, question, cypher_current, error, timeout=300):
    def _correct():
        messages = prompt_correction(
            schema_context=schema,  # ← SỬA ĐÂY
            question=question,
            cypher_current=cypher_current,
            error=error
        )

        inputs = tokenizer.apply_chat_template(
            messages,
            tokenize=True,
            add_generation_prompt=True,
            return_tensors="pt",
        ).to(model.device)

        attention_mask = (inputs != tokenizer.pad_token_id).long()

        model_generate_parameters = {
            "max_new_tokens": 512,
            "temperature": 0.1,
            "do_sample": True,
            "top_p": 0.9,
            "use_cache": True,
            "pad_token_id": tokenizer.eos_token_id,
        }

        with torch.no_grad():
            outputs = model.generate(
                input_ids=inputs,
                attention_mask=attention_mask,
                **model_generate_parameters
            )

        generated_tokens = outputs[0][inputs.shape[1]:]
        raw_output = tokenizer.decode(generated_tokens, skip_special_tokens=True)

        corrected_cypher = extract_cypher(raw_output, model_name)

        return corrected_cypher

    try:
        return func_timeout(timeout, _correct)
    except FunctionTimedOut:
        return "time_error"
    except Exception as e:
        return "error"

# %%
def cypher_self_correction(
    cypher_initial,
    alias,
    schema_context,
    question,
    max_retries=3,
    timeout=900
):
    cypher_current = cypher_initial
    retry = 0
    errors_history = []

    while retry < max_retries:
        success, error = execute_cypher(cypher_current, alias, timeout=timeout)

        if success:
            return {
                "success": True,
                "final_cypher": cypher_current,
                "retries": retry,
                "errors": errors_history
            }

        errors_history.append(f"Retry {retry}: {error}")

        cypher_corrected = llm_correct_cypher(
            schema=schema_context,
            question=question,
            cypher_current=cypher_current,
            error=error
        )

        if cypher_corrected in ["error", "time_error", None, ""]:
            break

        cypher_current = cypher_corrected
        retry += 1

    return {
        "success": False,
        "final_cypher": cypher_current,
        "retries": retry,
        "errors": errors_history
    }

# %%
def cypher_explain_correction(
    cypher_initial,
    driver,
    schema_context,
    question,
    max_retries=3,
    timeout=900
):
    cypher_current = cypher_initial
    retry = 0
    errors_history = []

    while retry < max_retries:
        success, error = explain_cypher(cypher_current, driver, timeout=timeout)

        if success:
            return {
                "success": True,
                "final_cypher": cypher_current,
                "retries": retry,
                "errors": errors_history
            }

        errors_history.append(f"Retry {retry}: {error}")

        cypher_corrected = llm_correct_cypher(
            schema=schema_context,
            question=question,
            cypher_current=cypher_current,
            error=error
        )

        if cypher_corrected in ["error", "time_error", None, ""]:
            break

        cypher_current = cypher_corrected
        retry += 1

    return {
        "success": False,
        "final_cypher": cypher_current,
        "retries": retry,
        "errors": errors_history
    }

# %%
def generate_cypher_with_correction(
    question,
    schema,
    alias,
    max_retries=3,
    timeout=1200,
    neo4j_timeout=180
):
    # Kiểm tra alias trước
    if pd.isna(alias) or alias is None or alias == "" or (isinstance(alias, str) and alias.strip() == ""):
        # Nếu alias không hợp lệ, sử dụng syntax validation với EXPLAIN
        def _execute_validation():
            cypher_initial = generate_cypher(question, schema)
            if cypher_initial in ["error", None]:
                return {
                    "cypher_initial": "error",
                    "schema": schema,
                    "correction_result": None,
                    "final_cypher": "error",
                    "success": False,
                    "retries": 0,
                    "errors": ["Failed to generate initial cypher"]
                }

            # Lấy driver đầu tiên để validate syntax
            first_alias = list(DRIVERS_BY_ALIAS.keys())[0] if DRIVERS_BY_ALIAS else DATABASE_ALIASES[0]
            driver = get_driver(first_alias)

            # Syntax validation loop với EXPLAIN
            validation_result = cypher_explain_correction(
                cypher_initial=cypher_initial,
                driver=driver,
                schema_context=schema,
                question=question,
                max_retries=max_retries,
                timeout=neo4j_timeout
            )

            final_cypher = validation_result.get("final_cypher")
            if final_cypher is None:
                final_cypher = "error"

            return {
                "cypher_initial": cypher_initial,
                "schema": schema,
                "correction_result": validation_result,
                "final_cypher": final_cypher,
                "success": validation_result.get("success"),
                "retries": validation_result.get("retries"),
                "errors": validation_result.get("errors")
            }

        try:
            result = func_timeout(timeout, _execute_validation)
            return result

        except FunctionTimedOut:
            return {
                "cypher_initial": "error",
                "schema": schema,
                "correction_result": None,
                "final_cypher": "error",
                "success": False,
                "retries": 0,
                "errors": [f"Total timeout reached after {timeout}s"]
            }
        except Exception as e:
            return {
                "cypher_initial": "error",
                "schema": schema,
                "correction_result": None,
                "final_cypher": "error",
                "success": False,
                "retries": 0,
                "errors": [f"Unexpected error: {str(e)}"]
            }

    # Alias hợp lệ - chạy execution thật
    def _execute_generation():
        cypher_initial = generate_cypher(question, schema)

        if cypher_initial in ["error", None]:
            return {
                "cypher_initial": "error",
                "schema": schema,
                "correction_result": None,
                "final_cypher": "error",
                "success": False,
                "retries": 0,
                "errors": ["Failed to generate initial cypher"]
            }

        # Self-correction loop
        correction_result = cypher_self_correction(
            cypher_initial=cypher_initial,
            alias=alias,
            schema_context=schema,
            question=question,
            max_retries=max_retries,
            timeout=neo4j_timeout
        )

        final_cypher = correction_result.get("final_cypher")
        if final_cypher is None:
            final_cypher = "error"

        return {
            "cypher_initial": cypher_initial,
            "schema": schema,
            "correction_result": correction_result,
            "final_cypher": final_cypher,
            "success": correction_result.get("success"),
            "retries": correction_result.get("retries"),
            "errors": correction_result.get("errors")
        }

    try:
        result = func_timeout(timeout, _execute_generation)
        return result

    except FunctionTimedOut:
        return {
            "cypher_initial": "error",
            "schema": schema,
            "correction_result": None,
            "final_cypher": "error",
            "success": False,
            "retries": 0,
            "errors": [f"Total timeout reached after {timeout}s"]
        }
    except Exception as e:
        return {
            "cypher_initial": "error",
            "schema": schema,
            "correction_result": None,
            "final_cypher": "error",
            "success": False,
            "retries": 0,
            "errors": [f"Unexpected error: {str(e)}"]
        }

# %%
# Lấy test case
first_row = test_df.iloc[0]
test_question = first_row['question']
test_schema = first_row['schema']
test_alias = first_row['database_reference_alias']

print("="*80)
print("TEST QUESTION:")
print("="*80)
print(test_question)

# Test 1: Extracted Cypher
print("\n" + "="*80)
print("TEST 1: generate_cypher() - EXTRACTED")
print("="*80)
result = generate_cypher_with_correction(
        question=test_question,
        schema=test_schema,
        alias=test_alias,
        max_retries=3,
        timeout=1200,
        neo4j_timeout=60
    )
print(f"Success: {result['success']}")
print(f"Retries: {result['retries']}")
print(f"Cypher Initial:\n{result['cypher_initial']}")
print(f"\nFinal Cypher:\n{result['final_cypher']}")
if result["errors"]:
    print("Errors:")
    for e in result["errors"]:
        print(e)

# Test 2: Expected
print("\n" + "="*80)
print("TEST 2: EXPECTED CYPHER")
print("="*80)
print(first_row['cypher'])
# Out:
# ================================================================================
# TEST QUESTION:
# ================================================================================
# Identify the 5 suppliers with the highest average unit price of products supplied.
#
# ================================================================================
# TEST 1: generate_cypher() - EXTRACTED
# ================================================================================
# alias
# Success: True
# Retries: 0
# Cypher Initial:
# MATCH (s:Supplier)-[:SUPPLIES]->(p:Product)
# WITH s, AVG(p.unitPrice) AS avgUnitPrice
# ORDER BY avgUnitPrice DESC
# LIMIT 5
# RETURN s.supplierID, s.companyName, avgUnitPrice
#
# Final Cypher:
# MATCH (s:Supplier)-[:SUPPLIES]->(p:Product)
# WITH s, AVG(p.unitPrice) AS avgUnitPrice
# ORDER BY avgUnitPrice DESC
# LIMIT 5
# RETURN s.supplierID, s.companyName, avgUnitPrice
#
# ================================================================================
# TEST 2: EXPECTED CYPHER
# ================================================================================
# MATCH (s:Supplier)-[:SUPPLIES]->(p:Product) WITH s, avg(p.unitPrice) AS avgUnitPrice ORDER BY avgUnitPrice DESC LIMIT 5 RETURN s.companyName AS Supplier, avgUnitPrice AS AverageUnitPrice

# %%
def run_batch_with_correction(
    test_df,
    checkpoint_path,
    max_retries=3,
    timeout=1200,
    neo4j_timeout=60,
    log_interval=100,
    save_interval=50
):
    """
    Chạy generation với self-correction và checkpoint support
    """
    # ==========================================================================
    # BƯỚC 1: Kiểm tra và load checkpoint
    if os.path.exists(checkpoint_path):
        print(f"[CHECKPOINT] Tìm thấy file checkpoint: {checkpoint_path}")
        df = pd.read_csv(checkpoint_path, encoding="utf-8-sig")
        print(f"[CHECKPOINT] Đã load {len(df)} dòng từ checkpoint")

        processed_count = df['cypher_generated'].notna().sum()
        print(f"[CHECKPOINT] Đã xử lý: {processed_count}/{len(df)} dòng")

    else:
        print(f"[CHECKPOINT] Không tìm thấy checkpoint, tạo mới từ test_df")
        df = test_df.copy()
        df['cypher_generated'] = ''
        df['success'] = ''
        df['retries'] = ''
        df['errors'] = ''

        df.to_csv(checkpoint_path, index=False, encoding='utf-8')
        print(f"[CHECKPOINT] Đã tạo file checkpoint: {checkpoint_path}")

    # ==========================================================================
    # BƯỚC 2: Xử lý các dòng chưa có kết quả
    total_rows = len(df)

    success_count = 0
    error_count = 0
    timeout_error_count = 0
    batch_start_idx = 0

    processed_since_last_save = 0

    print(f"\n{'='*80}")
    print(f"BẮT ĐẦU XỬ LÝ - Tổng số dòng: {total_rows}")
    print(f"Model: neo4j/text2cypher-gemma-2-9b-it-finetuned-2024v1")
    print(f"Self-correction: max_retries={max_retries}, neo4j_timeout={neo4j_timeout}s")
    print(f"{'='*80}\n")

    start_time = time.time()

    for idx in range(total_rows):
        current_cypher = df.at[idx, 'cypher_generated']

        if pd.notna(current_cypher) and str(current_cypher).strip() != '':
            continue

        # ======================================================================
        # XỬ LÝ DÒNG CHƯA CÓ KẾT QUẢ
        print(f"[Processing] Dòng {idx}...", end=" ", flush=True)

        try:
            question = df.at[idx, 'question']
            schema = df.at[idx, 'schema']
            alias = df.at[idx, 'database_reference_alias']

            result = generate_cypher_with_correction(
                question=question,
                schema=schema,
                alias=alias,
                max_retries=max_retries,
                timeout=timeout,
                neo4j_timeout=neo4j_timeout
            )

            df.at[idx, 'cypher_generated'] = result['final_cypher']
            df.at[idx, 'success'] = result['success']
            df.at[idx, 'retries'] = result['retries']
            df.at[idx, 'errors'] = str(result['errors'])

            cypher_result = result['final_cypher']

            if cypher_result == "error":
                error_count += 1
                print("ERROR")
            elif cypher_result == "time_error":
                timeout_error_count += 1
                print("TIMEOUT")
            else:
                success_count += 1
                print(f"SUCCESS (retries: {result['retries']})")

            processed_since_last_save += 1

        except Exception as e:
            print(f"ERROR - {str(e)}")
            df.at[idx, 'cypher_generated'] = "error"
            df.at[idx, 'success'] = False
            df.at[idx, 'retries'] = 0
            df.at[idx, 'errors'] = str(e)
            error_count += 1
            processed_since_last_save += 1

        # ======================================================================
        # LƯU CHECKPOINT
        # ======================================================================
        if processed_since_last_save >= save_interval:
            df.to_csv(checkpoint_path, index=False, encoding='utf-8')
            print(f"[CHECKPOINT] Đã lưu sau {processed_since_last_save} dòng")
            processed_since_last_save = 0

        # ======================================================================
        # LOG THỐNG KÊ
        # ======================================================================
        if (idx + 1) % log_interval == 0:
            elapsed_time = time.time() - start_time
            avg_time_per_row = elapsed_time / (idx + 1)
            remaining_rows = total_rows - (idx + 1)
            estimated_time = avg_time_per_row * remaining_rows

            print(f"\n{'='*80}")
            print(f"[LOG] Dòng {batch_start_idx}-{idx}")
            print(f"{'='*80}")
            print(f"Thành công:     {success_count}")
            print(f"Error:          {error_count}")
            print(f"Timeout Error:  {timeout_error_count}")
            print(f"Tổng xử lý:     {success_count + error_count + timeout_error_count}")
            print(f"Tiến độ:        {idx + 1}/{total_rows} ({(idx + 1)/total_rows*100:.2f}%)")
            print(f"Thời gian:      {elapsed_time/60:.2f} phút")
            print(f"Ước tính còn:   {estimated_time/60:.2f} phút")
            print(f"{'='*80}\n")

            success_count = 0
            error_count = 0
            timeout_error_count = 0
            batch_start_idx = idx + 1

    # ==========================================================================
    # LƯU CHECKPOINT CUỐI CÙNG
    # ==========================================================================
    if processed_since_last_save > 0:
        df.to_csv(checkpoint_path, index=False, encoding='utf-8')
        print(f"[CHECKPOINT] Đã lưu {processed_since_last_save} dòng cuối cùng")

    # ==========================================================================
    # KẾT THÚC - LOG CUỐI CÙNG
    # ==========================================================================
    total_time = time.time() - start_time

    final_success = (df['cypher_generated'].notna() &
                     (df['cypher_generated'] != 'error') &
                     (df['cypher_generated'] != 'time_error') &
                     (df['cypher_generated'] != '')).sum()
    final_error = (df['cypher_generated'] == 'error').sum()
    final_timeout = (df['cypher_generated'] == 'time_error').sum()

    print(f"\n{'='*80}")
    print(f"HOÀN THÀNH")
    print(f"{'='*80}")
    print(f"Tổng số dòng:        {total_rows}")
    print(f"Thành công:          {final_success} ({final_success/total_rows*100:.2f}%)")
    print(f"Error:               {final_error} ({final_error/total_rows*100:.2f}%)")
    print(f"Timeout Error:       {final_timeout} ({final_timeout/total_rows*100:.2f}%)")
    print(f"Tổng thời gian:      {total_time/60:.2f} phút")
    print(f"Thời gian trung bình: {total_time/total_rows:.2f} giây/dòng")
    print(f"Kết quả đã lưu tại:  {checkpoint_path}")
    print(f"{'='*80}\n")

    return df

print("✓ run_batch_with_correction loaded")
# Out:
# ✓ run_batch_with_correction loaded

# %%
df_results = run_batch_with_correction(
    test_df=test_df,
    checkpoint_path=checkpoint_path,
    max_retries=3,
    timeout=1200,
    neo4j_timeout=60,
    log_interval=100,
    save_interval=50
)
# Out:
# [CHECKPOINT] Không tìm thấy checkpoint, tạo mới từ test_df
# [CHECKPOINT] Đã tạo file checkpoint: /content/drive/MyDrive/T2C_qwen_bs_loop/qwen_bs_loop.csv
#
# ================================================================================
# BẮT ĐẦU XỬ LÝ - Tổng số dòng: 4833
# Model: neo4j/text2cypher-gemma-2-9b-it-finetuned-2024v1
# Self-correction: max_retries=3, neo4j_timeout=60s
# ================================================================================
#
# [Processing] Dòng 0... SUCCESS (retries: 0)
# [Processing] Dòng 1... SUCCESS (retries: 0)
# [Processing] Dòng 2... SUCCESS (retries: 0)
# [Processing] Dòng 3... SUCCESS (retries: 0)
# [Processing] Dòng 4... SUCCESS (retries: 0)
# [Processing] Dòng 5... SUCCESS (retries: 0)
# [Processing] Dòng 6... SUCCESS (retries: 0)
# [Processing] Dòng 7... SUCCESS (retries: 0)
# [Processing] Dòng 8... SUCCESS (retries: 0)
# [Processing] Dòng 9... SUCCESS (retries: 0)
# [Processing] Dòng 10... SUCCESS (retries: 0)
# [Processing] Dòng 11... SUCCESS (retries: 0)
# [Processing] Dòng 12... SUCCESS (retries: 0)
# [Processing] Dòng 13... SUCCESS (retries: 0)
# [Processing] Dòng 14... SUCCESS (retries: 2)
# [Processing] Dòng 15... SUCCESS (retries: 1)
# [Processing] Dòng 16... SUCCESS (retries: 0)
# [Processing] Dòng 17... SUCCESS (retries: 0)
# [Processing] Dòng 18... SUCCESS (retries: 3)
# [Processing] Dòng 19... SUCCESS (retries: 0)
# [Processing] Dòng 20... SUCCESS (retries: 0)
# [Processing] Dòng 21... SUCCESS (retries: 0)
# [Processing] Dòng 22... SUCCESS (retries: 0)
# [Processing] Dòng 23... SUCCESS (retries: 1)
# [Processing] Dòng 24... SUCCESS (retries: 0)
# [Processing] Dòng 25... SUCCESS (retries: 0)
# [Processing] Dòng 26... SUCCESS (retries: 0)
# [Processing] Dòng 27... SUCCESS (retries: 3)
# [Processing] Dòng 28... SUCCESS (retries: 3)
# [Processing] Dòng 29... SUCCESS (retries: 3)
# [Processing] Dòng 30... SUCCESS (retries: 0)
# [Processing] Dòng 31... SUCCESS (retries: 0)
# [Processing] Dòng 32... SUCCESS (retries: 1)
# [Processing] Dòng 33... SUCCESS (retries: 3)
# [Processing] Dòng 34... SUCCESS (retries: 0)
# [Processing] Dòng 35... SUCCESS (retries: 0)
# [Processing] Dòng 36... SUCCESS (retries: 3)
# [Processing] Dòng 37... SUCCESS (retries: 0)
# [Processing] Dòng 38... SUCCESS (retries: 0)
# [Processing] Dòng 39... SUCCESS (retries: 0)
# [Processing] Dòng 40... SUCCESS (retries: 0)
# [Processing] Dòng 41... SUCCESS (retries: 0)
# [Processing] Dòng 42... SUCCESS (retries: 0)
# [Processing] Dòng 43... SUCCESS (retries: 0)
# [Processing] Dòng 44... SUCCESS (retries: 0)
# [Processing] Dòng 45... SUCCESS (retries: 0)
# [Processing] Dòng 46... SUCCESS (retries: 1)
# [Processing] Dòng 47... SUCCESS (retries: 1)
# [Processing] Dòng 48... SUCCESS (retries: 0)
# [Processing] Dòng 49... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
# [Processing] Dòng 50... SUCCESS (retries: 0)
# [Processing] Dòng 51... SUCCESS (retries: 0)
# [Processing] Dòng 52... SUCCESS (retries: 0)
# [Processing] Dòng 53... SUCCESS (retries: 0)
# [Processing] Dòng 54... SUCCESS (retries: 0)
# [Processing] Dòng 55... SUCCESS (retries: 0)
# [Processing] Dòng 56... SUCCESS (retries: 0)
# [Processing] Dòng 57... SUCCESS (retries: 0)
# [Processing] Dòng 58... SUCCESS (retries: 0)
# [Processing] Dòng 59... SUCCESS (retries: 0)
# [Processing] Dòng 60... SUCCESS (retries: 0)
# [Processing] Dòng 61... SUCCESS (retries: 0)
# [Processing] Dòng 62... SUCCESS (retries: 0)
# [Processing] Dòng 63... SUCCESS (retries: 0)
# [Processing] Dòng 64... SUCCESS (retries: 0)
# [Processing] Dòng 65... SUCCESS (retries: 0)
# [Processing] Dòng 66... SUCCESS (retries: 0)
# [Processing] Dòng 67... SUCCESS (retries: 0)
# [Processing] Dòng 68... SUCCESS (retries: 0)
# [Processing] Dòng 69... SUCCESS (retries: 0)
# [Processing] Dòng 70... SUCCESS (retries: 3)
# [Processing] Dòng 71... SUCCESS (retries: 1)
# [Processing] Dòng 72... SUCCESS (retries: 0)
# [Processing] Dòng 73... SUCCESS (retries: 0)
# [Processing] Dòng 74... SUCCESS (retries: 0)
# [Processing] Dòng 75... SUCCESS (retries: 0)
# [Processing] Dòng 76... SUCCESS (retries: 0)
# [Processing] Dòng 77... SUCCESS (retries: 1)
# [Processing] Dòng 78... SUCCESS (retries: 0)
# [Processing] Dòng 79... SUCCESS (retries: 0)
# [Processing] Dòng 80... SUCCESS (retries: 0)
# [Processing] Dòng 81... SUCCESS (retries: 0)
# [Processing] Dòng 82... SUCCESS (retries: 0)
# [Processing] Dòng 83... SUCCESS (retries: 0)
# [Processing] Dòng 84... SUCCESS (retries: 0)
# [Processing] Dòng 85... SUCCESS (retries: 0)
# [Processing] Dòng 86... SUCCESS (retries: 0)
# [Processing] Dòng 87... SUCCESS (retries: 3)
# [Processing] Dòng 88... SUCCESS (retries: 0)
# [Processing] Dòng 89... SUCCESS (retries: 0)
# [Processing] Dòng 90... SUCCESS (retries: 0)
# [Processing] Dòng 91... SUCCESS (retries: 0)
# [Processing] Dòng 92... SUCCESS (retries: 0)
# [Processing] Dòng 93... SUCCESS (retries: 0)
# [Processing] Dòng 94... SUCCESS (retries: 0)
# [Processing] Dòng 95... SUCCESS (retries: 0)
# [Processing] Dòng 96... SUCCESS (retries: 0)
# [Processing] Dòng 97... SUCCESS (retries: 0)
# [Processing] Dòng 98... SUCCESS (retries: 1)
# [Processing] Dòng 99... SUCCESS (retries: 1)
# [CHECKPOINT] Đã lưu sau 50 dòng
#
# ================================================================================
# [LOG] Dòng 0-99
# ================================================================================
# Thành công:     100
# Error:          0
# Timeout Error:  0
# Tổng xử lý:     100
# Tiến độ:        100/4833 (2.07%)
# Thời gian:      9.12 phút
# Ước tính còn:   431.88 phút
# ================================================================================
#
# [Processing] Dòng 100... SUCCESS (retries: 0)
# [Processing] Dòng 101... SUCCESS (retries: 0)
# [Processing] Dòng 102... SUCCESS (retries: 0)
# [Processing] Dòng 103... SUCCESS (retries: 0)
# [Processing] Dòng 104... SUCCESS (retries: 0)
# [Processing] Dòng 105... SUCCESS (retries: 1)
# [Processing] Dòng 106... SUCCESS (retries: 0)
# [Processing] Dòng 107... SUCCESS (retries: 0)
# [Processing] Dòng 108... SUCCESS (retries: 0)
# [Processing] Dòng 109... SUCCESS (retries: 0)
# [Processing] Dòng 110... SUCCESS (retries: 0)
# [Processing] Dòng 111... SUCCESS (retries: 0)
# [Processing] Dòng 112... SUCCESS (retries: 0)
# [Processing] Dòng 113... SUCCESS (retries: 3)
# [Processing] Dòng 114... SUCCESS (retries: 0)
# [Processing] Dòng 115... SUCCESS (retries: 3)
# [Processing] Dòng 116... SUCCESS (retries: 0)
# [Processing] Dòng 117... SUCCESS (retries: 0)
# [Processing] Dòng 118... SUCCESS (retries: 0)
# [Processing] Dòng 119... SUCCESS (retries: 0)
# [Processing] Dòng 120... SUCCESS (retries: 0)
# [Processing] Dòng 121... SUCCESS (retries: 0)
# [Processing] Dòng 122... SUCCESS (retries: 0)
# [Processing] Dòng 123... SUCCESS (retries: 0)
# [Processing] Dòng 124... SUCCESS (retries: 3)
# [Processing] Dòng 125... SUCCESS (retries: 0)
# [Processing] Dòng 126... SUCCESS (retries: 0)
# [Processing] Dòng 127... SUCCESS (retries: 0)
# [Processing] Dòng 128... SUCCESS (retries: 0)
# [Processing] Dòng 129... SUCCESS (retries: 0)
# [Processing] Dòng 130... SUCCESS (retries: 0)
# [Processing] Dòng 131... SUCCESS (retries: 0)
# [Processing] Dòng 132... SUCCESS (retries: 0)
# [Processing] Dòng 133... SUCCESS (retries: 0)
# [Processing] Dòng 134... SUCCESS (retries: 0)
# [Processing] Dòng 135... SUCCESS (retries: 0)
# [Processing] Dòng 136... SUCCESS (retries: 0)
# [Processing] Dòng 137... SUCCESS (retries: 0)
# [Processing] Dòng 138... SUCCESS (retries: 2)
# [Processing] Dòng 139... SUCCESS (retries: 0)
# [Processing] Dòng 140... SUCCESS (retries: 0)
# [Processing] Dòng 141... SUCCESS (retries: 0)
# [Processing] Dòng 142... SUCCESS (retries: 0)
# [Processing] Dòng 143... SUCCESS (retries: 3)
# [Processing] Dòng 144... SUCCESS (retries: 0)
# [Processing] Dòng 145... SUCCESS (retries: 0)
# [Processing] Dòng 146... SUCCESS (retries: 0)
# [Processing] Dòng 147... SUCCESS (retries: 0)
# [Processing] Dòng 148... SUCCESS (retries: 0)
# [Processing] Dòng 149... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
# [Processing] Dòng 150... SUCCESS (retries: 0)
# [Processing] Dòng 151... SUCCESS (retries: 0)
# [Processing] Dòng 152... SUCCESS (retries: 1)
# [Processing] Dòng 153... SUCCESS (retries: 3)
# [Processing] Dòng 154... SUCCESS (retries: 3)
# [Processing] Dòng 155... SUCCESS (retries: 0)
# [Processing] Dòng 156... SUCCESS (retries: 0)
# [Processing] Dòng 157... SUCCESS (retries: 0)
# [Processing] Dòng 158... SUCCESS (retries: 0)
# [Processing] Dòng 159... SUCCESS (retries: 0)
# [Processing] Dòng 160... SUCCESS (retries: 0)
# [Processing] Dòng 161... SUCCESS (retries: 0)
# [Processing] Dòng 162... SUCCESS (retries: 0)
# [Processing] Dòng 163... SUCCESS (retries: 0)
# [Processing] Dòng 164... SUCCESS (retries: 0)
# [Processing] Dòng 165... SUCCESS (retries: 0)
# [Processing] Dòng 166... SUCCESS (retries: 0)
# [Processing] Dòng 167... SUCCESS (retries: 0)
# [Processing] Dòng 168... SUCCESS (retries: 0)
# [Processing] Dòng 169... SUCCESS (retries: 0)
# [Processing] Dòng 170... ERROR
# [Processing] Dòng 171... SUCCESS (retries: 0)
# [Processing] Dòng 172... SUCCESS (retries: 0)
# [Processing] Dòng 173... SUCCESS (retries: 0)
# [Processing] Dòng 174... SUCCESS (retries: 0)
# [Processing] Dòng 175... SUCCESS (retries: 0)
# [Processing] Dòng 176... SUCCESS (retries: 0)
# [Processing] Dòng 177... SUCCESS (retries: 0)
# [Processing] Dòng 178... SUCCESS (retries: 0)
# [Processing] Dòng 179... SUCCESS (retries: 0)
# [Processing] Dòng 180... SUCCESS (retries: 0)
# [Processing] Dòng 181... SUCCESS (retries: 0)
# [Processing] Dòng 182... SUCCESS (retries: 0)
# [Processing] Dòng 183... SUCCESS (retries: 0)
# [Processing] Dòng 184... SUCCESS (retries: 0)
# [Processing] Dòng 185... SUCCESS (retries: 0)
# [Processing] Dòng 186... SUCCESS (retries: 1)
# [Processing] Dòng 187... SUCCESS (retries: 0)
# [Processing] Dòng 188... SUCCESS (retries: 0)
# [Processing] Dòng 189... SUCCESS (retries: 0)
# [Processing] Dòng 190... SUCCESS (retries: 0)
# [Processing] Dòng 191... SUCCESS (retries: 0)
# [Processing] Dòng 192... SUCCESS (retries: 0)
# [Processing] Dòng 193... SUCCESS (retries: 0)
# [Processing] Dòng 194... SUCCESS (retries: 0)
# [Processing] Dòng 195... SUCCESS (retries: 0)
# [Processing] Dòng 196... SUCCESS (retries: 2)
# [Processing] Dòng 197... SUCCESS (retries: 0)
# [Processing] Dòng 198... SUCCESS (retries: 0)
# [Processing] Dòng 199... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
#
# ================================================================================
# [LOG] Dòng 100-199
# ================================================================================
# Thành công:     99
# Error:          1
# Timeout Error:  0
# Tổng xử lý:     100
# Tiến độ:        200/4833 (4.14%)
# Thời gian:      37.60 phút
# Ước tính còn:   870.97 phút
# ================================================================================
#
# [Processing] Dòng 200... SUCCESS (retries: 0)
# [Processing] Dòng 201... SUCCESS (retries: 0)
# [Processing] Dòng 202... SUCCESS (retries: 0)
# [Processing] Dòng 203... SUCCESS (retries: 0)
# [Processing] Dòng 204... SUCCESS (retries: 0)
# [Processing] Dòng 205... SUCCESS (retries: 0)
# [Processing] Dòng 206... SUCCESS (retries: 0)
# [Processing] Dòng 207... SUCCESS (retries: 3)
# [Processing] Dòng 208... SUCCESS (retries: 1)
# [Processing] Dòng 209... SUCCESS (retries: 0)
# [Processing] Dòng 210... SUCCESS (retries: 0)
# [Processing] Dòng 211... SUCCESS (retries: 1)
# [Processing] Dòng 212... SUCCESS (retries: 0)
# [Processing] Dòng 213... SUCCESS (retries: 0)
# [Processing] Dòng 214... SUCCESS (retries: 0)
# [Processing] Dòng 215... SUCCESS (retries: 0)
# [Processing] Dòng 216... SUCCESS (retries: 3)
# [Processing] Dòng 217... SUCCESS (retries: 0)
# [Processing] Dòng 218... SUCCESS (retries: 0)
# [Processing] Dòng 219... SUCCESS (retries: 0)
# [Processing] Dòng 220... SUCCESS (retries: 0)
# [Processing] Dòng 221... SUCCESS (retries: 1)
# [Processing] Dòng 222... SUCCESS (retries: 3)
# [Processing] Dòng 223... SUCCESS (retries: 0)
# [Processing] Dòng 224... SUCCESS (retries: 0)
# [Processing] Dòng 225... SUCCESS (retries: 0)
# [Processing] Dòng 226... SUCCESS (retries: 1)
# [Processing] Dòng 227... SUCCESS (retries: 0)
# [Processing] Dòng 228... SUCCESS (retries: 0)
# [Processing] Dòng 229... SUCCESS (retries: 0)
# [Processing] Dòng 230... SUCCESS (retries: 0)
# [Processing] Dòng 231... SUCCESS (retries: 3)
# [Processing] Dòng 232... SUCCESS (retries: 0)
# [Processing] Dòng 233... SUCCESS (retries: 0)
# [Processing] Dòng 234... SUCCESS (retries: 0)
# [Processing] Dòng 235... SUCCESS (retries: 1)
# [Processing] Dòng 236... SUCCESS (retries: 0)
# [Processing] Dòng 237... SUCCESS (retries: 0)
# [Processing] Dòng 238... SUCCESS (retries: 0)
# [Processing] Dòng 239... SUCCESS (retries: 0)
# [Processing] Dòng 240... SUCCESS (retries: 0)
# [Processing] Dòng 241... SUCCESS (retries: 3)
# [Processing] Dòng 242... SUCCESS (retries: 0)
# [Processing] Dòng 243... SUCCESS (retries: 2)
# [Processing] Dòng 244... SUCCESS (retries: 0)
# [Processing] Dòng 245... SUCCESS (retries: 0)
# [Processing] Dòng 246... SUCCESS (retries: 0)
# [Processing] Dòng 247... SUCCESS (retries: 0)
# [Processing] Dòng 248... SUCCESS (retries: 0)
# [Processing] Dòng 249... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
# [Processing] Dòng 250... SUCCESS (retries: 0)
# [Processing] Dòng 251... SUCCESS (retries: 0)
# [Processing] Dòng 252... SUCCESS (retries: 1)
# [Processing] Dòng 253... SUCCESS (retries: 0)
# [Processing] Dòng 254... SUCCESS (retries: 0)
# [Processing] Dòng 255... SUCCESS (retries: 1)
# [Processing] Dòng 256... SUCCESS (retries: 0)
# [Processing] Dòng 257... SUCCESS (retries: 0)
# [Processing] Dòng 258... SUCCESS (retries: 0)
# [Processing] Dòng 259... SUCCESS (retries: 0)
# [Processing] Dòng 260... SUCCESS (retries: 0)
# [Processing] Dòng 261... SUCCESS (retries: 0)
# [Processing] Dòng 262... SUCCESS (retries: 0)
# [Processing] Dòng 263... SUCCESS (retries: 0)
# [Processing] Dòng 264... SUCCESS (retries: 0)
# [Processing] Dòng 265... SUCCESS (retries: 0)
# [Processing] Dòng 266... SUCCESS (retries: 0)
# [Processing] Dòng 267... SUCCESS (retries: 0)
# [Processing] Dòng 268... SUCCESS (retries: 0)
# [Processing] Dòng 269... SUCCESS (retries: 0)
# [Processing] Dòng 270... SUCCESS (retries: 0)
# [Processing] Dòng 271... SUCCESS (retries: 0)
# [Processing] Dòng 272... SUCCESS (retries: 0)
# [Processing] Dòng 273... SUCCESS (retries: 0)
# [Processing] Dòng 274... SUCCESS (retries: 0)
# [Processing] Dòng 275... SUCCESS (retries: 0)
# [Processing] Dòng 276... SUCCESS (retries: 3)
# [Processing] Dòng 277... SUCCESS (retries: 0)
# [Processing] Dòng 278... SUCCESS (retries: 0)
# [Processing] Dòng 279... SUCCESS (retries: 0)
# [Processing] Dòng 280... SUCCESS (retries: 0)
# [Processing] Dòng 281... SUCCESS (retries: 0)
# [Processing] Dòng 282... SUCCESS (retries: 0)
# [Processing] Dòng 283... SUCCESS (retries: 0)
# [Processing] Dòng 284... SUCCESS (retries: 0)
# [Processing] Dòng 285... SUCCESS (retries: 0)
# [Processing] Dòng 286... SUCCESS (retries: 3)
# [Processing] Dòng 287... SUCCESS (retries: 0)
# [Processing] Dòng 288... SUCCESS (retries: 0)
# [Processing] Dòng 289... SUCCESS (retries: 0)
# [Processing] Dòng 290... SUCCESS (retries: 0)
# [Processing] Dòng 291... SUCCESS (retries: 0)
# [Processing] Dòng 292... SUCCESS (retries: 0)
# [Processing] Dòng 293... SUCCESS (retries: 1)
# [Processing] Dòng 294... SUCCESS (retries: 0)
# [Processing] Dòng 295... SUCCESS (retries: 0)
# [Processing] Dòng 296... SUCCESS (retries: 0)
# [Processing] Dòng 297... SUCCESS (retries: 0)
# [Processing] Dòng 298... SUCCESS (retries: 0)
# [Processing] Dòng 299... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
#
# ================================================================================
# [LOG] Dòng 200-299
# ================================================================================
# Thành công:     100
# Error:          0
# Timeout Error:  0
# Tổng xử lý:     100
# Tiến độ:        300/4833 (6.21%)
# Thời gian:      48.24 phút
# Ước tính còn:   728.91 phút
# ================================================================================
#
# [Processing] Dòng 300... SUCCESS (retries: 0)
# [Processing] Dòng 301... SUCCESS (retries: 1)
# [Processing] Dòng 302... SUCCESS (retries: 0)
# [Processing] Dòng 303... SUCCESS (retries: 0)
# [Processing] Dòng 304... SUCCESS (retries: 0)
# [Processing] Dòng 305... SUCCESS (retries: 0)
# [Processing] Dòng 306... SUCCESS (retries: 0)
# [Processing] Dòng 307... SUCCESS (retries: 1)
# [Processing] Dòng 308... SUCCESS (retries: 0)
# [Processing] Dòng 309... SUCCESS (retries: 0)
# [Processing] Dòng 310... SUCCESS (retries: 0)
# [Processing] Dòng 311... SUCCESS (retries: 0)
# [Processing] Dòng 312... SUCCESS (retries: 0)
# [Processing] Dòng 313... SUCCESS (retries: 0)
# [Processing] Dòng 314... SUCCESS (retries: 1)
# [Processing] Dòng 315... SUCCESS (retries: 3)
# [Processing] Dòng 316... SUCCESS (retries: 0)
# [Processing] Dòng 317... SUCCESS (retries: 0)
# [Processing] Dòng 318... SUCCESS (retries: 0)
# [Processing] Dòng 319... SUCCESS (retries: 0)
# [Processing] Dòng 320... SUCCESS (retries: 0)
# [Processing] Dòng 321... SUCCESS (retries: 0)
# [Processing] Dòng 322... SUCCESS (retries: 0)
# [Processing] Dòng 323... SUCCESS (retries: 0)
# [Processing] Dòng 324... SUCCESS (retries: 3)
# [Processing] Dòng 325... SUCCESS (retries: 0)
# [Processing] Dòng 326... SUCCESS (retries: 1)
# [Processing] Dòng 327... SUCCESS (retries: 1)
# [Processing] Dòng 328... SUCCESS (retries: 0)
# [Processing] Dòng 329... SUCCESS (retries: 0)
# [Processing] Dòng 330... SUCCESS (retries: 0)
# [Processing] Dòng 331... SUCCESS (retries: 3)
# [Processing] Dòng 332... SUCCESS (retries: 0)
# [Processing] Dòng 333... SUCCESS (retries: 0)
# [Processing] Dòng 334... SUCCESS (retries: 0)
# [Processing] Dòng 335... SUCCESS (retries: 0)
# [Processing] Dòng 336... SUCCESS (retries: 0)
# [Processing] Dòng 337... SUCCESS (retries: 3)
# [Processing] Dòng 338... SUCCESS (retries: 0)
# [Processing] Dòng 339... SUCCESS (retries: 3)
# [Processing] Dòng 340... SUCCESS (retries: 0)
# [Processing] Dòng 341... SUCCESS (retries: 0)
# [Processing] Dòng 342... SUCCESS (retries: 0)
# [Processing] Dòng 343... SUCCESS (retries: 0)
# [Processing] Dòng 344... SUCCESS (retries: 0)
# [Processing] Dòng 345... SUCCESS (retries: 0)
# [Processing] Dòng 346... SUCCESS (retries: 0)
# [Processing] Dòng 347... SUCCESS (retries: 1)
# [Processing] Dòng 348... SUCCESS (retries: 0)
# [Processing] Dòng 349... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
# [Processing] Dòng 350... SUCCESS (retries: 0)
# [Processing] Dòng 351... SUCCESS (retries: 0)
# [Processing] Dòng 352... SUCCESS (retries: 0)
# [Processing] Dòng 353... SUCCESS (retries: 0)
# [Processing] Dòng 354... SUCCESS (retries: 0)
# [Processing] Dòng 355... SUCCESS (retries: 0)
# [Processing] Dòng 356... SUCCESS (retries: 0)
# [Processing] Dòng 357... SUCCESS (retries: 0)
# [Processing] Dòng 358... SUCCESS (retries: 0)
# [Processing] Dòng 359... SUCCESS (retries: 0)
# [Processing] Dòng 360... SUCCESS (retries: 0)
# [Processing] Dòng 361... SUCCESS (retries: 0)
# [Processing] Dòng 362... SUCCESS (retries: 0)
# [Processing] Dòng 363... SUCCESS (retries: 0)
# [Processing] Dòng 364... SUCCESS (retries: 0)
# [Processing] Dòng 365... SUCCESS (retries: 0)
# [Processing] Dòng 366... SUCCESS (retries: 0)
# [Processing] Dòng 367... SUCCESS (retries: 0)
# [Processing] Dòng 368... SUCCESS (retries: 0)
# [Processing] Dòng 369... SUCCESS (retries: 0)
# [Processing] Dòng 370... SUCCESS (retries: 3)
# [Processing] Dòng 371... SUCCESS (retries: 0)
# [Processing] Dòng 372... SUCCESS (retries: 0)
# [Processing] Dòng 373... SUCCESS (retries: 0)
# [Processing] Dòng 374... SUCCESS (retries: 0)
# [Processing] Dòng 375... SUCCESS (retries: 0)
# [Processing] Dòng 376... SUCCESS (retries: 0)
# [Processing] Dòng 377... SUCCESS (retries: 0)
# [Processing] Dòng 378... SUCCESS (retries: 0)
# [Processing] Dòng 379... SUCCESS (retries: 0)
# [Processing] Dòng 380... SUCCESS (retries: 0)
# [Processing] Dòng 381... SUCCESS (retries: 0)
# [Processing] Dòng 382... SUCCESS (retries: 3)
# [Processing] Dòng 383... SUCCESS (retries: 0)
# [Processing] Dòng 384... SUCCESS (retries: 0)
# [Processing] Dòng 385... SUCCESS (retries: 0)
# [Processing] Dòng 386... SUCCESS (retries: 1)
# [Processing] Dòng 387... SUCCESS (retries: 0)
# [Processing] Dòng 388... SUCCESS (retries: 0)
# [Processing] Dòng 389... SUCCESS (retries: 0)
# [Processing] Dòng 390... SUCCESS (retries: 3)
# [Processing] Dòng 391... SUCCESS (retries: 0)
# [Processing] Dòng 392... SUCCESS (retries: 3)
# [Processing] Dòng 393... SUCCESS (retries: 1)
# [Processing] Dòng 394... SUCCESS (retries: 0)
# [Processing] Dòng 395... SUCCESS (retries: 0)
# [Processing] Dòng 396... SUCCESS (retries: 0)
# [Processing] Dòng 397... SUCCESS (retries: 0)
# [Processing] Dòng 398... SUCCESS (retries: 0)
# [Processing] Dòng 399... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
#
# ================================================================================
# [LOG] Dòng 300-399
# ================================================================================
# Thành công:     100
# Error:          0
# Timeout Error:  0
# Tổng xử lý:     100
# Tiến độ:        400/4833 (8.28%)
# Thời gian:      56.01 phút
# Ước tính còn:   620.77 phút
# ================================================================================
#
# [Processing] Dòng 400... SUCCESS (retries: 0)
# [Processing] Dòng 401... SUCCESS (retries: 0)
# [Processing] Dòng 402... SUCCESS (retries: 0)
# [Processing] Dòng 403... SUCCESS (retries: 0)
# [Processing] Dòng 404... SUCCESS (retries: 0)
# [Processing] Dòng 405... SUCCESS (retries: 0)
# [Processing] Dòng 406... SUCCESS (retries: 0)
# [Processing] Dòng 407... SUCCESS (retries: 0)
# [Processing] Dòng 408... SUCCESS (retries: 0)
# [Processing] Dòng 409... SUCCESS (retries: 1)
# [Processing] Dòng 410... SUCCESS (retries: 0)
# [Processing] Dòng 411... SUCCESS (retries: 1)
# [Processing] Dòng 412... SUCCESS (retries: 0)
# [Processing] Dòng 413... SUCCESS (retries: 0)
# [Processing] Dòng 414... SUCCESS (retries: 0)
# [Processing] Dòng 415... SUCCESS (retries: 0)
# [Processing] Dòng 416... SUCCESS (retries: 0)
# [Processing] Dòng 417... SUCCESS (retries: 0)
# [Processing] Dòng 418... SUCCESS (retries: 0)
# [Processing] Dòng 419... SUCCESS (retries: 0)
# [Processing] Dòng 420... SUCCESS (retries: 0)
# [Processing] Dòng 421... SUCCESS (retries: 0)
# [Processing] Dòng 422... SUCCESS (retries: 0)
# [Processing] Dòng 423... SUCCESS (retries: 3)
# [Processing] Dòng 424... SUCCESS (retries: 0)
# [Processing] Dòng 425... SUCCESS (retries: 0)
# [Processing] Dòng 426... SUCCESS (retries: 0)
# [Processing] Dòng 427... SUCCESS (retries: 0)
# [Processing] Dòng 428... SUCCESS (retries: 0)
# [Processing] Dòng 429... SUCCESS (retries: 1)
# [Processing] Dòng 430... SUCCESS (retries: 0)
# [Processing] Dòng 431... SUCCESS (retries: 3)
# [Processing] Dòng 432... SUCCESS (retries: 2)
# [Processing] Dòng 433... SUCCESS (retries: 3)
# [Processing] Dòng 434... SUCCESS (retries: 2)
# [Processing] Dòng 435... SUCCESS (retries: 0)
# [Processing] Dòng 436... SUCCESS (retries: 0)
# [Processing] Dòng 437... SUCCESS (retries: 0)
# [Processing] Dòng 438... SUCCESS (retries: 0)
# [Processing] Dòng 439... SUCCESS (retries: 0)
# [Processing] Dòng 440... SUCCESS (retries: 0)
# [Processing] Dòng 441... SUCCESS (retries: 0)
# [Processing] Dòng 442... SUCCESS (retries: 1)
# [Processing] Dòng 443... SUCCESS (retries: 0)
# [Processing] Dòng 444... SUCCESS (retries: 0)
# [Processing] Dòng 445... SUCCESS (retries: 1)
# [Processing] Dòng 446... SUCCESS (retries: 3)
# [Processing] Dòng 447... SUCCESS (retries: 0)
# [Processing] Dòng 448... SUCCESS (retries: 0)
# [Processing] Dòng 449... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
# [Processing] Dòng 450... SUCCESS (retries: 1)
# [Processing] Dòng 451... SUCCESS (retries: 0)
# [Processing] Dòng 452... SUCCESS (retries: 0)
# [Processing] Dòng 453... SUCCESS (retries: 0)
# [Processing] Dòng 454... SUCCESS (retries: 3)
# [Processing] Dòng 455... SUCCESS (retries: 0)
# [Processing] Dòng 456... SUCCESS (retries: 1)
# [Processing] Dòng 457... SUCCESS (retries: 0)
# [Processing] Dòng 458... SUCCESS (retries: 0)
# [Processing] Dòng 459... SUCCESS (retries: 0)
# [Processing] Dòng 460... SUCCESS (retries: 0)
# [Processing] Dòng 461... SUCCESS (retries: 0)
# [Processing] Dòng 462... SUCCESS (retries: 0)
# [Processing] Dòng 463... SUCCESS (retries: 0)
# [Processing] Dòng 464... SUCCESS (retries: 0)
# [Processing] Dòng 465... SUCCESS (retries: 0)
# [Processing] Dòng 466... SUCCESS (retries: 0)
# [Processing] Dòng 467... SUCCESS (retries: 1)
# [Processing] Dòng 468... SUCCESS (retries: 0)
# [Processing] Dòng 469... SUCCESS (retries: 0)
# [Processing] Dòng 470... SUCCESS (retries: 0)
# [Processing] Dòng 471... SUCCESS (retries: 0)
# [Processing] Dòng 472... SUCCESS (retries: 0)
# [Processing] Dòng 473... SUCCESS (retries: 0)
# [Processing] Dòng 474... SUCCESS (retries: 1)
# [Processing] Dòng 475... SUCCESS (retries: 3)
# [Processing] Dòng 476... SUCCESS (retries: 0)
# [Processing] Dòng 477... SUCCESS (retries: 0)
# [Processing] Dòng 478... SUCCESS (retries: 0)
# [Processing] Dòng 479... SUCCESS (retries: 3)
# [Processing] Dòng 480... SUCCESS (retries: 0)
# [Processing] Dòng 481... SUCCESS (retries: 3)
# [Processing] Dòng 482... SUCCESS (retries: 0)
# [Processing] Dòng 483... SUCCESS (retries: 0)
# [Processing] Dòng 484... SUCCESS (retries: 0)
# [Processing] Dòng 485... SUCCESS (retries: 1)
# [Processing] Dòng 486... SUCCESS (retries: 1)
# [Processing] Dòng 487... SUCCESS (retries: 0)
# [Processing] Dòng 488... SUCCESS (retries: 0)
# [Processing] Dòng 489... SUCCESS (retries: 0)
# [Processing] Dòng 490... SUCCESS (retries: 0)
# [Processing] Dòng 491... SUCCESS (retries: 0)
# [Processing] Dòng 492... SUCCESS (retries: 0)
# [Processing] Dòng 493... SUCCESS (retries: 3)
# [Processing] Dòng 494... SUCCESS (retries: 0)
# [Processing] Dòng 495... SUCCESS (retries: 0)
# [Processing] Dòng 496... SUCCESS (retries: 0)
# [Processing] Dòng 497... SUCCESS (retries: 0)
# [Processing] Dòng 498... SUCCESS (retries: 3)
# [Processing] Dòng 499... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
#
# ================================================================================
# [LOG] Dòng 400-499
# ================================================================================
# Thành công:     100
# Error:          0
# Timeout Error:  0
# Tổng xử lý:     100
# Tiến độ:        500/4833 (10.35%)
# Thời gian:      65.61 phút
# Ước tính còn:   568.54 phút
# ================================================================================
#
# [Processing] Dòng 500... SUCCESS (retries: 0)
# [Processing] Dòng 501... SUCCESS (retries: 0)
# [Processing] Dòng 502... SUCCESS (retries: 0)
# [Processing] Dòng 503... SUCCESS (retries: 0)
# [Processing] Dòng 504... SUCCESS (retries: 0)
# [Processing] Dòng 505... SUCCESS (retries: 0)
# [Processing] Dòng 506... SUCCESS (retries: 0)
# [Processing] Dòng 507... SUCCESS (retries: 0)
# [Processing] Dòng 508... SUCCESS (retries: 0)
# [Processing] Dòng 509... SUCCESS (retries: 3)
# [Processing] Dòng 510... SUCCESS (retries: 0)
# [Processing] Dòng 511... SUCCESS (retries: 0)
# [Processing] Dòng 512... SUCCESS (retries: 3)
# [Processing] Dòng 513... SUCCESS (retries: 3)
# [Processing] Dòng 514... SUCCESS (retries: 0)
# [Processing] Dòng 515... SUCCESS (retries: 0)
# [Processing] Dòng 516... SUCCESS (retries: 0)
# [Processing] Dòng 517... SUCCESS (retries: 0)
# [Processing] Dòng 518... SUCCESS (retries: 0)
# [Processing] Dòng 519... SUCCESS (retries: 0)
# [Processing] Dòng 520... SUCCESS (retries: 0)
# [Processing] Dòng 521... SUCCESS (retries: 0)
# [Processing] Dòng 522... SUCCESS (retries: 0)
# [Processing] Dòng 523... SUCCESS (retries: 0)
# [Processing] Dòng 524... SUCCESS (retries: 0)
# [Processing] Dòng 525... SUCCESS (retries: 0)
# [Processing] Dòng 526... SUCCESS (retries: 0)
# [Processing] Dòng 527... SUCCESS (retries: 0)
# [Processing] Dòng 528... SUCCESS (retries: 0)
# [Processing] Dòng 529... SUCCESS (retries: 0)
# [Processing] Dòng 530... SUCCESS (retries: 3)
# [Processing] Dòng 531... SUCCESS (retries: 0)
# [Processing] Dòng 532... SUCCESS (retries: 0)
# [Processing] Dòng 533... SUCCESS (retries: 2)
# [Processing] Dòng 534... SUCCESS (retries: 0)
# [Processing] Dòng 535... SUCCESS (retries: 0)
# [Processing] Dòng 536... SUCCESS (retries: 0)
# [Processing] Dòng 537... SUCCESS (retries: 0)
# [Processing] Dòng 538... SUCCESS (retries: 0)
# [Processing] Dòng 539... SUCCESS (retries: 0)
# [Processing] Dòng 540... SUCCESS (retries: 0)
# [Processing] Dòng 541... SUCCESS (retries: 3)
# [Processing] Dòng 542... SUCCESS (retries: 0)
# [Processing] Dòng 543... SUCCESS (retries: 0)
# [Processing] Dòng 544... SUCCESS (retries: 3)
# [Processing] Dòng 545... SUCCESS (retries: 1)
# [Processing] Dòng 546... SUCCESS (retries: 0)
# [Processing] Dòng 547... SUCCESS (retries: 0)
# [Processing] Dòng 548... SUCCESS (retries: 0)
# [Processing] Dòng 549... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
# [Processing] Dòng 550... SUCCESS (retries: 0)
# [Processing] Dòng 551... SUCCESS (retries: 0)
# [Processing] Dòng 552... SUCCESS (retries: 0)
# [Processing] Dòng 553... SUCCESS (retries: 0)
# [Processing] Dòng 554... SUCCESS (retries: 0)
# [Processing] Dòng 555... SUCCESS (retries: 0)
# [Processing] Dòng 556... SUCCESS (retries: 0)
# [Processing] Dòng 557... SUCCESS (retries: 0)
# [Processing] Dòng 558... SUCCESS (retries: 0)
# [Processing] Dòng 559... SUCCESS (retries: 0)
# [Processing] Dòng 560... SUCCESS (retries: 0)
# [Processing] Dòng 561... SUCCESS (retries: 0)
# [Processing] Dòng 562... SUCCESS (retries: 0)
# [Processing] Dòng 563... SUCCESS (retries: 0)
# [Processing] Dòng 564... SUCCESS (retries: 0)
# [Processing] Dòng 565... SUCCESS (retries: 3)
# [Processing] Dòng 566... SUCCESS (retries: 0)
# [Processing] Dòng 567... SUCCESS (retries: 0)
# [Processing] Dòng 568... SUCCESS (retries: 0)
# [Processing] Dòng 569... SUCCESS (retries: 3)
# [Processing] Dòng 570... SUCCESS (retries: 0)
# [Processing] Dòng 571... SUCCESS (retries: 0)
# [Processing] Dòng 572... SUCCESS (retries: 1)
# [Processing] Dòng 573... SUCCESS (retries: 0)
# [Processing] Dòng 574... SUCCESS (retries: 0)
# [Processing] Dòng 575... SUCCESS (retries: 0)
# [Processing] Dòng 576... SUCCESS (retries: 3)
# [Processing] Dòng 577... SUCCESS (retries: 0)
# [Processing] Dòng 578... SUCCESS (retries: 0)
# [Processing] Dòng 579... SUCCESS (retries: 1)
# [Processing] Dòng 580... SUCCESS (retries: 0)
# [Processing] Dòng 581... SUCCESS (retries: 0)
# [Processing] Dòng 582... SUCCESS (retries: 0)
# [Processing] Dòng 583... SUCCESS (retries: 0)
# [Processing] Dòng 584... SUCCESS (retries: 0)
# [Processing] Dòng 585... SUCCESS (retries: 1)
# [Processing] Dòng 586... SUCCESS (retries: 0)
# [Processing] Dòng 587... SUCCESS (retries: 0)
# [Processing] Dòng 588... SUCCESS (retries: 0)
# [Processing] Dòng 589... SUCCESS (retries: 2)
# [Processing] Dòng 590... SUCCESS (retries: 0)
# [Processing] Dòng 591... SUCCESS (retries: 0)
# [Processing] Dòng 592... SUCCESS (retries: 0)
# [Processing] Dòng 593... SUCCESS (retries: 0)
# [Processing] Dòng 594... SUCCESS (retries: 0)
# [Processing] Dòng 595... SUCCESS (retries: 0)
# [Processing] Dòng 596... SUCCESS (retries: 0)
# [Processing] Dòng 597... SUCCESS (retries: 0)
# [Processing] Dòng 598... SUCCESS (retries: 0)
# [Processing] Dòng 599... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
#
# ================================================================================
# [LOG] Dòng 500-599
# ================================================================================
# Thành công:     100
# Error:          0
# Timeout Error:  0
# Tổng xử lý:     100
# Tiến độ:        600/4833 (12.41%)
# Thời gian:      74.67 phút
# Ước tính còn:   526.83 phút
# ================================================================================
#
# [Processing] Dòng 600... SUCCESS (retries: 0)
# [Processing] Dòng 601... SUCCESS (retries: 0)
# [Processing] Dòng 602... SUCCESS (retries: 3)
# [Processing] Dòng 603... SUCCESS (retries: 0)
# [Processing] Dòng 604... SUCCESS (retries: 0)
# [Processing] Dòng 605... SUCCESS (retries: 0)
# [Processing] Dòng 606... SUCCESS (retries: 0)
# [Processing] Dòng 607... SUCCESS (retries: 0)
# [Processing] Dòng 608... SUCCESS (retries: 0)
# [Processing] Dòng 609... SUCCESS (retries: 0)
# [Processing] Dòng 610... SUCCESS (retries: 0)
# [Processing] Dòng 611... SUCCESS (retries: 3)
# [Processing] Dòng 612... SUCCESS (retries: 1)
# [Processing] Dòng 613... SUCCESS (retries: 0)
# [Processing] Dòng 614... SUCCESS (retries: 0)
# [Processing] Dòng 615... SUCCESS (retries: 3)
# [Processing] Dòng 616... SUCCESS (retries: 0)
# [Processing] Dòng 617... SUCCESS (retries: 0)
# [Processing] Dòng 618... SUCCESS (retries: 3)
# [Processing] Dòng 619... SUCCESS (retries: 0)
# [Processing] Dòng 620... SUCCESS (retries: 0)
# [Processing] Dòng 621... SUCCESS (retries: 0)
# [Processing] Dòng 622... SUCCESS (retries: 0)
# [Processing] Dòng 623... SUCCESS (retries: 1)
# [Processing] Dòng 624... SUCCESS (retries: 1)
# [Processing] Dòng 625... SUCCESS (retries: 0)
# [Processing] Dòng 626... SUCCESS (retries: 1)
# [Processing] Dòng 627... SUCCESS (retries: 0)
# [Processing] Dòng 628... SUCCESS (retries: 0)
# [Processing] Dòng 629... SUCCESS (retries: 0)
# [Processing] Dòng 630... SUCCESS (retries: 0)
# [Processing] Dòng 631... SUCCESS (retries: 0)
# [Processing] Dòng 632... SUCCESS (retries: 0)
# [Processing] Dòng 633... SUCCESS (retries: 0)
# [Processing] Dòng 634... SUCCESS (retries: 3)
# [Processing] Dòng 635... SUCCESS (retries: 0)
# [Processing] Dòng 636... SUCCESS (retries: 0)
# [Processing] Dòng 637... SUCCESS (retries: 1)
# [Processing] Dòng 638... SUCCESS (retries: 0)
# [Processing] Dòng 639... SUCCESS (retries: 0)
# [Processing] Dòng 640... SUCCESS (retries: 0)
# [Processing] Dòng 641... SUCCESS (retries: 0)
# [Processing] Dòng 642... SUCCESS (retries: 0)
# [Processing] Dòng 643... SUCCESS (retries: 0)
# [Processing] Dòng 644... SUCCESS (retries: 0)
# [Processing] Dòng 645... SUCCESS (retries: 0)
# [Processing] Dòng 646... SUCCESS (retries: 0)
# [Processing] Dòng 647... SUCCESS (retries: 0)
# [Processing] Dòng 648... SUCCESS (retries: 0)
# [Processing] Dòng 649... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
# [Processing] Dòng 650... SUCCESS (retries: 0)
# [Processing] Dòng 651... SUCCESS (retries: 0)
# [Processing] Dòng 652... SUCCESS (retries: 0)
# [Processing] Dòng 653... SUCCESS (retries: 0)
# [Processing] Dòng 654... SUCCESS (retries: 0)
# [Processing] Dòng 655... SUCCESS (retries: 0)
# [Processing] Dòng 656... SUCCESS (retries: 0)
# [Processing] Dòng 657... SUCCESS (retries: 3)
# [Processing] Dòng 658... SUCCESS (retries: 0)
# [Processing] Dòng 659... SUCCESS (retries: 0)
# [Processing] Dòng 660... SUCCESS (retries: 0)
# [Processing] Dòng 661... SUCCESS (retries: 0)
# [Processing] Dòng 662... SUCCESS (retries: 0)
# [Processing] Dòng 663... SUCCESS (retries: 0)
# [Processing] Dòng 664... SUCCESS (retries: 3)
# [Processing] Dòng 665... SUCCESS (retries: 0)
# [Processing] Dòng 666... SUCCESS (retries: 0)
# [Processing] Dòng 667... SUCCESS (retries: 0)
# [Processing] Dòng 668... SUCCESS (retries: 0)
# [Processing] Dòng 669... SUCCESS (retries: 0)
# [Processing] Dòng 670... SUCCESS (retries: 0)
# [Processing] Dòng 671... SUCCESS (retries: 0)
# [Processing] Dòng 672... SUCCESS (retries: 3)
# [Processing] Dòng 673... SUCCESS (retries: 1)
# [Processing] Dòng 674... SUCCESS (retries: 0)
# [Processing] Dòng 675... SUCCESS (retries: 0)
# [Processing] Dòng 676... SUCCESS (retries: 0)
# [Processing] Dòng 677... SUCCESS (retries: 3)
# [Processing] Dòng 678... SUCCESS (retries: 3)
# [Processing] Dòng 679... SUCCESS (retries: 1)
# [Processing] Dòng 680... SUCCESS (retries: 0)
# [Processing] Dòng 681... SUCCESS (retries: 0)
# [Processing] Dòng 682... SUCCESS (retries: 0)
# [Processing] Dòng 683... SUCCESS (retries: 0)
# [Processing] Dòng 684... SUCCESS (retries: 0)
# [Processing] Dòng 685... SUCCESS (retries: 0)
# [Processing] Dòng 686... SUCCESS (retries: 0)
# [Processing] Dòng 687... SUCCESS (retries: 0)
# [Processing] Dòng 688... SUCCESS (retries: 0)
# [Processing] Dòng 689... SUCCESS (retries: 0)
# [Processing] Dòng 690... SUCCESS (retries: 2)
# [Processing] Dòng 691... SUCCESS (retries: 0)
# [Processing] Dòng 692... SUCCESS (retries: 0)
# [Processing] Dòng 693... SUCCESS (retries: 0)
# [Processing] Dòng 694... SUCCESS (retries: 0)
# [Processing] Dòng 695... SUCCESS (retries: 0)
# [Processing] Dòng 696... SUCCESS (retries: 0)
# [Processing] Dòng 697... SUCCESS (retries: 0)
# [Processing] Dòng 698... SUCCESS (retries: 0)
# [Processing] Dòng 699... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
#
# ================================================================================
# [LOG] Dòng 600-699
# ================================================================================
# Thành công:     100
# Error:          0
# Timeout Error:  0
# Tổng xử lý:     100
# Tiến độ:        700/4833 (14.48%)
# Thời gian:      82.88 phút
# Ước tính còn:   489.37 phút
# ================================================================================
#
# [Processing] Dòng 700... SUCCESS (retries: 0)
# [Processing] Dòng 701... SUCCESS (retries: 0)
# [Processing] Dòng 702... SUCCESS (retries: 0)
# [Processing] Dòng 703... SUCCESS (retries: 0)
# [Processing] Dòng 704... SUCCESS (retries: 0)
# [Processing] Dòng 705... SUCCESS (retries: 1)
# [Processing] Dòng 706... SUCCESS (retries: 0)
# [Processing] Dòng 707... SUCCESS (retries: 0)
# [Processing] Dòng 708... SUCCESS (retries: 1)
# [Processing] Dòng 709... SUCCESS (retries: 0)
# [Processing] Dòng 710... SUCCESS (retries: 2)
# [Processing] Dòng 711... SUCCESS (retries: 0)
# [Processing] Dòng 712... SUCCESS (retries: 1)
# [Processing] Dòng 713... SUCCESS (retries: 3)
# [Processing] Dòng 714... SUCCESS (retries: 0)
# [Processing] Dòng 715... SUCCESS (retries: 0)
# [Processing] Dòng 716... SUCCESS (retries: 1)
# [Processing] Dòng 717... SUCCESS (retries: 0)
# [Processing] Dòng 718... SUCCESS (retries: 1)
# [Processing] Dòng 719... SUCCESS (retries: 0)
# [Processing] Dòng 720... SUCCESS (retries: 0)
# [Processing] Dòng 721... SUCCESS (retries: 0)
# [Processing] Dòng 722... SUCCESS (retries: 0)
# [Processing] Dòng 723... SUCCESS (retries: 0)
# [Processing] Dòng 724... SUCCESS (retries: 0)
# [Processing] Dòng 725... SUCCESS (retries: 0)
# [Processing] Dòng 726... SUCCESS (retries: 0)
# [Processing] Dòng 727... SUCCESS (retries: 3)
# [Processing] Dòng 728... SUCCESS (retries: 0)
# [Processing] Dòng 729... SUCCESS (retries: 0)
# [Processing] Dòng 730... SUCCESS (retries: 0)
# [Processing] Dòng 731... SUCCESS (retries: 0)
# [Processing] Dòng 732... SUCCESS (retries: 1)
# [Processing] Dòng 733... SUCCESS (retries: 0)
# [Processing] Dòng 734... SUCCESS (retries: 1)
# [Processing] Dòng 735... SUCCESS (retries: 0)
# [Processing] Dòng 736... SUCCESS (retries: 0)
# [Processing] Dòng 737... SUCCESS (retries: 0)
# [Processing] Dòng 738... SUCCESS (retries: 0)
# [Processing] Dòng 739... SUCCESS (retries: 0)
# [Processing] Dòng 740... SUCCESS (retries: 0)
# [Processing] Dòng 741... SUCCESS (retries: 1)
# [Processing] Dòng 742... SUCCESS (retries: 1)
# [Processing] Dòng 743... SUCCESS (retries: 0)
# [Processing] Dòng 744... SUCCESS (retries: 0)
# [Processing] Dòng 745... SUCCESS (retries: 0)
# [Processing] Dòng 746... SUCCESS (retries: 0)
# [Processing] Dòng 747... SUCCESS (retries: 0)
# [Processing] Dòng 748... SUCCESS (retries: 0)
# [Processing] Dòng 749... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
# [Processing] Dòng 750... SUCCESS (retries: 0)
# [Processing] Dòng 751... SUCCESS (retries: 0)
# [Processing] Dòng 752... SUCCESS (retries: 0)
# [Processing] Dòng 753... SUCCESS (retries: 0)
# [Processing] Dòng 754... SUCCESS (retries: 3)
# [Processing] Dòng 755... SUCCESS (retries: 0)
# [Processing] Dòng 756... SUCCESS (retries: 0)
# [Processing] Dòng 757... SUCCESS (retries: 0)
# [Processing] Dòng 758... SUCCESS (retries: 0)
# [Processing] Dòng 759... SUCCESS (retries: 0)
# [Processing] Dòng 760... SUCCESS (retries: 2)
# [Processing] Dòng 761... SUCCESS (retries: 0)
# [Processing] Dòng 762... SUCCESS (retries: 0)
# [Processing] Dòng 763... SUCCESS (retries: 3)
# [Processing] Dòng 764... SUCCESS (retries: 0)
# [Processing] Dòng 765... SUCCESS (retries: 3)
# [Processing] Dòng 766... SUCCESS (retries: 0)
# [Processing] Dòng 767... SUCCESS (retries: 0)
# [Processing] Dòng 768... SUCCESS (retries: 3)
# [Processing] Dòng 769... SUCCESS (retries: 0)
# [Processing] Dòng 770... SUCCESS (retries: 0)
# [Processing] Dòng 771... SUCCESS (retries: 1)
# [Processing] Dòng 772... SUCCESS (retries: 0)
# [Processing] Dòng 773... SUCCESS (retries: 0)
# [Processing] Dòng 774... SUCCESS (retries: 0)
# [Processing] Dòng 775... SUCCESS (retries: 0)
# [Processing] Dòng 776... SUCCESS (retries: 0)
# [Processing] Dòng 777... SUCCESS (retries: 0)
# [Processing] Dòng 778... SUCCESS (retries: 0)
# [Processing] Dòng 779... SUCCESS (retries: 3)
# [Processing] Dòng 780... SUCCESS (retries: 1)
# [Processing] Dòng 781... SUCCESS (retries: 0)
# [Processing] Dòng 782... SUCCESS (retries: 0)
# [Processing] Dòng 783... SUCCESS (retries: 0)
# [Processing] Dòng 784... SUCCESS (retries: 0)
# [Processing] Dòng 785... SUCCESS (retries: 0)
# [Processing] Dòng 786... SUCCESS (retries: 0)
# [Processing] Dòng 787... SUCCESS (retries: 0)
# [Processing] Dòng 788... SUCCESS (retries: 0)
# [Processing] Dòng 789... SUCCESS (retries: 0)
# [Processing] Dòng 790... SUCCESS (retries: 0)
# [Processing] Dòng 791... SUCCESS (retries: 0)
# [Processing] Dòng 792... SUCCESS (retries: 3)
# [Processing] Dòng 793... SUCCESS (retries: 0)
# [Processing] Dòng 794... SUCCESS (retries: 0)
# [Processing] Dòng 795... SUCCESS (retries: 3)
# [Processing] Dòng 796... SUCCESS (retries: 0)
# [Processing] Dòng 797... SUCCESS (retries: 0)
# [Processing] Dòng 798... SUCCESS (retries: 0)
# [Processing] Dòng 799... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
#
# ================================================================================
# [LOG] Dòng 700-799
# ================================================================================
# Thành công:     100
# Error:          0
# Timeout Error:  0
# Tổng xử lý:     100
# Tiến độ:        800/4833 (16.55%)
# Thời gian:      92.05 phút
# Ước tính còn:   464.05 phút
# ================================================================================
#
# [Processing] Dòng 800... SUCCESS (retries: 0)
# [Processing] Dòng 801... SUCCESS (retries: 3)
# [Processing] Dòng 802... SUCCESS (retries: 0)
# [Processing] Dòng 803... SUCCESS (retries: 0)
# [Processing] Dòng 804... SUCCESS (retries: 3)
# [Processing] Dòng 805... SUCCESS (retries: 0)
# [Processing] Dòng 806... SUCCESS (retries: 0)
# [Processing] Dòng 807... SUCCESS (retries: 0)
# [Processing] Dòng 808... SUCCESS (retries: 0)
# [Processing] Dòng 809... SUCCESS (retries: 0)
# [Processing] Dòng 810... SUCCESS (retries: 0)
# [Processing] Dòng 811... SUCCESS (retries: 0)
# [Processing] Dòng 812... SUCCESS (retries: 3)
# [Processing] Dòng 813... SUCCESS (retries: 0)
# [Processing] Dòng 814... SUCCESS (retries: 0)
# [Processing] Dòng 815... SUCCESS (retries: 0)
# [Processing] Dòng 816... SUCCESS (retries: 0)
# [Processing] Dòng 817... SUCCESS (retries: 0)
# [Processing] Dòng 818... SUCCESS (retries: 1)
# [Processing] Dòng 819... SUCCESS (retries: 0)
# [Processing] Dòng 820... SUCCESS (retries: 3)
# [Processing] Dòng 821... SUCCESS (retries: 0)
# [Processing] Dòng 822... SUCCESS (retries: 0)
# [Processing] Dòng 823... SUCCESS (retries: 0)
# [Processing] Dòng 824... SUCCESS (retries: 0)
# [Processing] Dòng 825... SUCCESS (retries: 0)
# [Processing] Dòng 826... SUCCESS (retries: 0)
# [Processing] Dòng 827... SUCCESS (retries: 0)
# [Processing] Dòng 828... SUCCESS (retries: 0)
# [Processing] Dòng 829... SUCCESS (retries: 0)
# [Processing] Dòng 830... SUCCESS (retries: 3)
# [Processing] Dòng 831... SUCCESS (retries: 0)
# [Processing] Dòng 832... SUCCESS (retries: 3)
# [Processing] Dòng 833... SUCCESS (retries: 0)
# [Processing] Dòng 834... SUCCESS (retries: 1)
# [Processing] Dòng 835... SUCCESS (retries: 0)
# [Processing] Dòng 836... SUCCESS (retries: 0)
# [Processing] Dòng 837... SUCCESS (retries: 0)
# [Processing] Dòng 838... SUCCESS (retries: 0)
# [Processing] Dòng 839... SUCCESS (retries: 0)
# [Processing] Dòng 840... SUCCESS (retries: 0)
# [Processing] Dòng 841... SUCCESS (retries: 0)
# [Processing] Dòng 842... SUCCESS (retries: 0)
# [Processing] Dòng 843... SUCCESS (retries: 0)
# [Processing] Dòng 844... SUCCESS (retries: 0)
# [Processing] Dòng 845... SUCCESS (retries: 0)
# [Processing] Dòng 846... SUCCESS (retries: 0)
# [Processing] Dòng 847... SUCCESS (retries: 3)
# [Processing] Dòng 848... SUCCESS (retries: 1)
# [Processing] Dòng 849... SUCCESS (retries: 3)
# [CHECKPOINT] Đã lưu sau 50 dòng
# [Processing] Dòng 850... SUCCESS (retries: 0)
# [Processing] Dòng 851... SUCCESS (retries: 0)
# [Processing] Dòng 852... SUCCESS (retries: 0)
# [Processing] Dòng 853... SUCCESS (retries: 0)
# [Processing] Dòng 854... SUCCESS (retries: 0)
# [Processing] Dòng 855... SUCCESS (retries: 0)
# [Processing] Dòng 856... SUCCESS (retries: 0)
# [Processing] Dòng 857... SUCCESS (retries: 0)
# [Processing] Dòng 858... SUCCESS (retries: 0)
# [Processing] Dòng 859... SUCCESS (retries: 0)
# [Processing] Dòng 860... SUCCESS (retries: 3)
# [Processing] Dòng 861... SUCCESS (retries: 0)
# [Processing] Dòng 862... SUCCESS (retries: 0)
# [Processing] Dòng 863... SUCCESS (retries: 0)
# [Processing] Dòng 864... SUCCESS (retries: 0)
# [Processing] Dòng 865... SUCCESS (retries: 1)
# [Processing] Dòng 866... SUCCESS (retries: 1)
# [Processing] Dòng 867... SUCCESS (retries: 0)
# [Processing] Dòng 868... SUCCESS (retries: 0)
# [Processing] Dòng 869... SUCCESS (retries: 0)
# [Processing] Dòng 870... SUCCESS (retries: 0)
# [Processing] Dòng 871... SUCCESS (retries: 0)
# [Processing] Dòng 872... SUCCESS (retries: 3)
# [Processing] Dòng 873... SUCCESS (retries: 0)
# [Processing] Dòng 874... SUCCESS (retries: 0)
# [Processing] Dòng 875... SUCCESS (retries: 0)
# [Processing] Dòng 876... SUCCESS (retries: 1)
# [Processing] Dòng 877... SUCCESS (retries: 0)
# [Processing] Dòng 878... SUCCESS (retries: 0)
# [Processing] Dòng 879... SUCCESS (retries: 0)
# [Processing] Dòng 880... SUCCESS (retries: 1)
# [Processing] Dòng 881... SUCCESS (retries: 0)
# [Processing] Dòng 882... SUCCESS (retries: 1)
# [Processing] Dòng 883... SUCCESS (retries: 0)
# [Processing] Dòng 884... SUCCESS (retries: 0)
# [Processing] Dòng 885... SUCCESS (retries: 0)
# [Processing] Dòng 886... SUCCESS (retries: 0)
# [Processing] Dòng 887... SUCCESS (retries: 0)
# [Processing] Dòng 888... SUCCESS (retries: 0)
# [Processing] Dòng 889... SUCCESS (retries: 0)
# [Processing] Dòng 890... SUCCESS (retries: 1)
# [Processing] Dòng 891... SUCCESS (retries: 3)
# [Processing] Dòng 892... SUCCESS (retries: 3)
# [Processing] Dòng 893... SUCCESS (retries: 3)
# [Processing] Dòng 894... SUCCESS (retries: 0)
# [Processing] Dòng 895... SUCCESS (retries: 1)
# [Processing] Dòng 896... SUCCESS (retries: 0)
# [Processing] Dòng 897... SUCCESS (retries: 0)
# [Processing] Dòng 898... SUCCESS (retries: 0)
# [Processing] Dòng 899... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
#
# ================================================================================
# [LOG] Dòng 800-899
# ================================================================================
# Thành công:     100
# Error:          0
# Timeout Error:  0
# Tổng xử lý:     100
# Tiến độ:        900/4833 (18.62%)
# Thời gian:      102.43 phút
# Ước tính còn:   447.61 phút
# ================================================================================
#
# [Processing] Dòng 900... SUCCESS (retries: 0)
# [Processing] Dòng 901... SUCCESS (retries: 0)
# [Processing] Dòng 902... SUCCESS (retries: 0)
# [Processing] Dòng 903... SUCCESS (retries: 1)
# [Processing] Dòng 904... SUCCESS (retries: 0)
# [Processing] Dòng 905... SUCCESS (retries: 0)
# [Processing] Dòng 906... SUCCESS (retries: 3)
# [Processing] Dòng 907... SUCCESS (retries: 0)
# [Processing] Dòng 908... SUCCESS (retries: 0)
# [Processing] Dòng 909... SUCCESS (retries: 0)
# [Processing] Dòng 910... SUCCESS (retries: 0)
# [Processing] Dòng 911... SUCCESS (retries: 3)
# [Processing] Dòng 912... SUCCESS (retries: 0)
# [Processing] Dòng 913... SUCCESS (retries: 0)
# [Processing] Dòng 914... SUCCESS (retries: 0)
# [Processing] Dòng 915... SUCCESS (retries: 1)
# [Processing] Dòng 916... SUCCESS (retries: 1)
# [Processing] Dòng 917... SUCCESS (retries: 0)
# [Processing] Dòng 918... SUCCESS (retries: 0)
# [Processing] Dòng 919... SUCCESS (retries: 0)
# [Processing] Dòng 920... SUCCESS (retries: 1)
# [Processing] Dòng 921... SUCCESS (retries: 0)
# [Processing] Dòng 922... SUCCESS (retries: 0)
# [Processing] Dòng 923... SUCCESS (retries: 0)
# [Processing] Dòng 924... SUCCESS (retries: 0)
# [Processing] Dòng 925... SUCCESS (retries: 0)
# [Processing] Dòng 926... SUCCESS (retries: 0)
# [Processing] Dòng 927... SUCCESS (retries: 0)
# [Processing] Dòng 928... SUCCESS (retries: 0)
# [Processing] Dòng 929... SUCCESS (retries: 3)
# [Processing] Dòng 930... SUCCESS (retries: 0)
# [Processing] Dòng 931... SUCCESS (retries: 0)
# [Processing] Dòng 932... SUCCESS (retries: 0)
# [Processing] Dòng 933... SUCCESS (retries: 0)
# [Processing] Dòng 934... SUCCESS (retries: 0)
# [Processing] Dòng 935... SUCCESS (retries: 0)
# [Processing] Dòng 936... SUCCESS (retries: 1)
# [Processing] Dòng 937... SUCCESS (retries: 0)
# [Processing] Dòng 938... SUCCESS (retries: 0)
# ...
# [Processing] Dòng 1546... SUCCESS (retries: 0)
# [Processing] Dòng 1547... SUCCESS (retries: 0)
# [Processing] Dòng 1548... SUCCESS (retries: 0)
# [Processing] Dòng 1549... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
# [Processing] Dòng 1550... SUCCESS (retries: 0)
# [Processing] Dòng 1551... SUCCESS (retries: 0)
# [Processing] Dòng 1552... SUCCESS (retries: 3)
# [Processing] Dòng 1553... SUCCESS (retries: 0)
# [Processing] Dòng 1554... SUCCESS (retries: 0)
# [Processing] Dòng 1555... SUCCESS (retries: 3)
# [Processing] Dòng 1556... SUCCESS (retries: 0)
# [Processing] Dòng 1557... SUCCESS (retries: 1)
# [Processing] Dòng 1558... SUCCESS (retries: 0)
# [Processing] Dòng 1559... SUCCESS (retries: 1)
# [Processing] Dòng 1560... SUCCESS (retries: 2)
# [Processing] Dòng 1561... SUCCESS (retries: 3)
# [Processing] Dòng 1562... SUCCESS (retries: 0)
# [Processing] Dòng 1563... SUCCESS (retries: 0)
# [Processing] Dòng 1564... SUCCESS (retries: 0)
# [Processing] Dòng 1565... SUCCESS (retries: 0)
# [Processing] Dòng 1566... SUCCESS (retries: 0)
# [Processing] Dòng 1567... SUCCESS (retries: 0)
# [Processing] Dòng 1568... SUCCESS (retries: 0)
# [Processing] Dòng 1569... SUCCESS (retries: 0)
# [Processing] Dòng 1570... SUCCESS (retries: 0)
# [Processing] Dòng 1571... SUCCESS (retries: 0)
# [Processing] Dòng 1572... SUCCESS (retries: 0)
# [Processing] Dòng 1573... SUCCESS (retries: 0)
# [Processing] Dòng 1574... SUCCESS (retries: 0)
# [Processing] Dòng 1575... SUCCESS (retries: 0)
# [Processing] Dòng 1576... SUCCESS (retries: 0)
# [Processing] Dòng 1577... SUCCESS (retries: 0)
# [Processing] Dòng 1578... SUCCESS (retries: 0)
# [Processing] Dòng 1579... SUCCESS (retries: 0)
# [Processing] Dòng 1580... SUCCESS (retries: 0)
# [Processing] Dòng 1581... SUCCESS (retries: 0)
# [Processing] Dòng 1582... SUCCESS (retries: 0)
# [Processing] Dòng 1583... SUCCESS (retries: 0)
# [Processing] Dòng 1584... SUCCESS (retries: 3)
# [Processing] Dòng 1585... SUCCESS (retries: 0)
# [Processing] Dòng 1586... SUCCESS (retries: 0)
# [Processing] Dòng 1587... SUCCESS (retries: 0)
# [Processing] Dòng 1588... SUCCESS (retries: 0)
# [Processing] Dòng 1589... SUCCESS (retries: 0)
# [Processing] Dòng 1590... SUCCESS (retries: 0)
# [Processing] Dòng 1591... SUCCESS (retries: 0)
# [Processing] Dòng 1592... SUCCESS (retries: 0)
# [Processing] Dòng 1593... SUCCESS (retries: 0)
# [Processing] Dòng 1594... SUCCESS (retries: 0)
# [Processing] Dòng 1595... SUCCESS (retries: 3)
# [Processing] Dòng 1596... SUCCESS (retries: 0)
# [Processing] Dòng 1597... SUCCESS (retries: 0)
# [Processing] Dòng 1598... SUCCESS (retries: 0)
# [Processing] Dòng 1599... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
#
# ================================================================================
# [LOG] Dòng 1500-1599
# ================================================================================
# Thành công:     100
# Error:          0
# Timeout Error:  0
# Tổng xử lý:     100
# Tiến độ:        1600/4833 (33.11%)
# Thời gian:      169.77 phút
# Ước tính còn:   343.03 phút
# ================================================================================
#
# [Processing] Dòng 1600... SUCCESS (retries: 0)
# [Processing] Dòng 1601... SUCCESS (retries: 1)
# [Processing] Dòng 1602... SUCCESS (retries: 3)
# [Processing] Dòng 1603... SUCCESS (retries: 0)
# [Processing] Dòng 1604... SUCCESS (retries: 0)
# [Processing] Dòng 1605... SUCCESS (retries: 0)
# [Processing] Dòng 1606... SUCCESS (retries: 3)
# [Processing] Dòng 1607... SUCCESS (retries: 0)
# [Processing] Dòng 1608... SUCCESS (retries: 0)
# [Processing] Dòng 1609... SUCCESS (retries: 0)
# [Processing] Dòng 1610... SUCCESS (retries: 3)
# [Processing] Dòng 1611... SUCCESS (retries: 0)
# [Processing] Dòng 1612... SUCCESS (retries: 0)
# [Processing] Dòng 1613... SUCCESS (retries: 3)
# [Processing] Dòng 1614... SUCCESS (retries: 0)
# [Processing] Dòng 1615... SUCCESS (retries: 0)
# [Processing] Dòng 1616... SUCCESS (retries: 0)
# [Processing] Dòng 1617... SUCCESS (retries: 3)
# [Processing] Dòng 1618... SUCCESS (retries: 0)
# [Processing] Dòng 1619... SUCCESS (retries: 0)
# [Processing] Dòng 1620... SUCCESS (retries: 0)
# [Processing] Dòng 1621... SUCCESS (retries: 0)
# [Processing] Dòng 1622... SUCCESS (retries: 0)
# [Processing] Dòng 1623... SUCCESS (retries: 0)
# [Processing] Dòng 1624... SUCCESS (retries: 0)
# [Processing] Dòng 1625... SUCCESS (retries: 0)
# [Processing] Dòng 1626... SUCCESS (retries: 2)
# [Processing] Dòng 1627... SUCCESS (retries: 2)
# [Processing] Dòng 1628... SUCCESS (retries: 0)
# [Processing] Dòng 1629... SUCCESS (retries: 0)
# [Processing] Dòng 1630... SUCCESS (retries: 0)
# [Processing] Dòng 1631... SUCCESS (retries: 0)
# [Processing] Dòng 1632... SUCCESS (retries: 0)
# [Processing] Dòng 1633... SUCCESS (retries: 0)
# [Processing] Dòng 1634... SUCCESS (retries: 0)
# [Processing] Dòng 1635... SUCCESS (retries: 1)
# [Processing] Dòng 1636... SUCCESS (retries: 1)
# [Processing] Dòng 1637... SUCCESS (retries: 1)
# [Processing] Dòng 1638... SUCCESS (retries: 0)
# [Processing] Dòng 1639... SUCCESS (retries: 1)
# [Processing] Dòng 1640... SUCCESS (retries: 0)
# [Processing] Dòng 1641... SUCCESS (retries: 0)
# [Processing] Dòng 1642... SUCCESS (retries: 0)
# [Processing] Dòng 1643... SUCCESS (retries: 0)
# [Processing] Dòng 1644... SUCCESS (retries: 0)
# [Processing] Dòng 1645... SUCCESS (retries: 0)
# [Processing] Dòng 1646... SUCCESS (retries: 0)
# [Processing] Dòng 1647... SUCCESS (retries: 0)
# [Processing] Dòng 1648... SUCCESS (retries: 0)
# [Processing] Dòng 1649... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
# [Processing] Dòng 1650... SUCCESS (retries: 0)
# [Processing] Dòng 1651... SUCCESS (retries: 0)
# [Processing] Dòng 1652... SUCCESS (retries: 0)
# [Processing] Dòng 1653... SUCCESS (retries: 0)
# [Processing] Dòng 1654... SUCCESS (retries: 0)
# [Processing] Dòng 1655... SUCCESS (retries: 0)
# [Processing] Dòng 1656... SUCCESS (retries: 3)
# [Processing] Dòng 1657... SUCCESS (retries: 0)
# [Processing] Dòng 1658... SUCCESS (retries: 0)
# [Processing] Dòng 1659... SUCCESS (retries: 0)
# [Processing] Dòng 1660... SUCCESS (retries: 0)
# [Processing] Dòng 1661... SUCCESS (retries: 0)
# [Processing] Dòng 1662... SUCCESS (retries: 0)
# [Processing] Dòng 1663... SUCCESS (retries: 0)
# [Processing] Dòng 1664... SUCCESS (retries: 3)
# [Processing] Dòng 1665... SUCCESS (retries: 0)
# [Processing] Dòng 1666... SUCCESS (retries: 0)
# [Processing] Dòng 1667... SUCCESS (retries: 3)
# [Processing] Dòng 1668... SUCCESS (retries: 0)
# [Processing] Dòng 1669... SUCCESS (retries: 0)
# [Processing] Dòng 1670... SUCCESS (retries: 0)
# [Processing] Dòng 1671... SUCCESS (retries: 0)
# [Processing] Dòng 1672... SUCCESS (retries: 0)
# [Processing] Dòng 1673... SUCCESS (retries: 0)
# [Processing] Dòng 1674... SUCCESS (retries: 0)
# [Processing] Dòng 1675... SUCCESS (retries: 2)
# [Processing] Dòng 1676... SUCCESS (retries: 0)
# [Processing] Dòng 1677... SUCCESS (retries: 0)
# [Processing] Dòng 1678... SUCCESS (retries: 3)
# [Processing] Dòng 1679... SUCCESS (retries: 0)
# [Processing] Dòng 1680... SUCCESS (retries: 0)
# [Processing] Dòng 1681... SUCCESS (retries: 0)
# [Processing] Dòng 1682... SUCCESS (retries: 1)
# [Processing] Dòng 1683... SUCCESS (retries: 0)
# [Processing] Dòng 1684... SUCCESS (retries: 0)
# [Processing] Dòng 1685... SUCCESS (retries: 0)
# [Processing] Dòng 1686... SUCCESS (retries: 0)
# [Processing] Dòng 1687... SUCCESS (retries: 0)
# [Processing] Dòng 1688... SUCCESS (retries: 0)
# [Processing] Dòng 1689... SUCCESS (retries: 0)
# [Processing] Dòng 1690... SUCCESS (retries: 0)
# [Processing] Dòng 1691... SUCCESS (retries: 0)
# [Processing] Dòng 1692... SUCCESS (retries: 3)
# [Processing] Dòng 1693... SUCCESS (retries: 0)
# [Processing] Dòng 1694... SUCCESS (retries: 0)
# [Processing] Dòng 1695... SUCCESS (retries: 0)
# [Processing] Dòng 1696... SUCCESS (retries: 3)
# [Processing] Dòng 1697... SUCCESS (retries: 0)
# [Processing] Dòng 1698... SUCCESS (retries: 0)
# [Processing] Dòng 1699... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
#
# ================================================================================
# [LOG] Dòng 1600-1699
# ================================================================================
# Thành công:     100
# Error:          0
# Timeout Error:  0
# Tổng xử lý:     100
# Tiến độ:        1700/4833 (35.17%)
# Thời gian:      178.86 phút
# Ước tính còn:   329.63 phút
# ================================================================================
#
# [Processing] Dòng 1700... SUCCESS (retries: 0)
# [Processing] Dòng 1701... SUCCESS (retries: 1)
# [Processing] Dòng 1702... SUCCESS (retries: 0)
# [Processing] Dòng 1703... SUCCESS (retries: 0)
# [Processing] Dòng 1704... SUCCESS (retries: 0)
# [Processing] Dòng 1705... SUCCESS (retries: 0)
# [Processing] Dòng 1706... SUCCESS (retries: 0)
# [Processing] Dòng 1707... SUCCESS (retries: 1)
# [Processing] Dòng 1708... SUCCESS (retries: 0)
# [Processing] Dòng 1709... SUCCESS (retries: 0)
# [Processing] Dòng 1710... SUCCESS (retries: 0)
# [Processing] Dòng 1711... SUCCESS (retries: 0)
# [Processing] Dòng 1712... SUCCESS (retries: 0)
# [Processing] Dòng 1713... SUCCESS (retries: 0)
# [Processing] Dòng 1714... SUCCESS (retries: 0)
# [Processing] Dòng 1715... SUCCESS (retries: 0)
# [Processing] Dòng 1716... SUCCESS (retries: 0)
# [Processing] Dòng 1717... SUCCESS (retries: 0)
# [Processing] Dòng 1718... SUCCESS (retries: 0)
# [Processing] Dòng 1719... SUCCESS (retries: 3)
# [Processing] Dòng 1720... SUCCESS (retries: 0)
# [Processing] Dòng 1721... SUCCESS (retries: 0)
# [Processing] Dòng 1722... SUCCESS (retries: 0)
# [Processing] Dòng 1723... SUCCESS (retries: 0)
# [Processing] Dòng 1724... SUCCESS (retries: 0)
# [Processing] Dòng 1725... SUCCESS (retries: 0)
# [Processing] Dòng 1726... SUCCESS (retries: 1)
# [Processing] Dòng 1727... SUCCESS (retries: 0)
# [Processing] Dòng 1728... SUCCESS (retries: 0)
# [Processing] Dòng 1729... SUCCESS (retries: 3)
# [Processing] Dòng 1730... SUCCESS (retries: 0)
# [Processing] Dòng 1731... SUCCESS (retries: 0)
# [Processing] Dòng 1732... SUCCESS (retries: 0)
# [Processing] Dòng 1733... SUCCESS (retries: 3)
# [Processing] Dòng 1734... SUCCESS (retries: 0)
# [Processing] Dòng 1735... SUCCESS (retries: 3)
# [Processing] Dòng 1736... SUCCESS (retries: 1)
# [Processing] Dòng 1737... SUCCESS (retries: 1)
# [Processing] Dòng 1738... SUCCESS (retries: 3)
# [Processing] Dòng 1739... SUCCESS (retries: 0)
# [Processing] Dòng 1740... SUCCESS (retries: 0)
# [Processing] Dòng 1741... SUCCESS (retries: 0)
# [Processing] Dòng 1742... SUCCESS (retries: 0)
# [Processing] Dòng 1743... SUCCESS (retries: 3)
# [Processing] Dòng 1744... SUCCESS (retries: 0)
# [Processing] Dòng 1745... SUCCESS (retries: 0)
# [Processing] Dòng 1746... SUCCESS (retries: 0)
# [Processing] Dòng 1747... SUCCESS (retries: 1)
# [Processing] Dòng 1748... SUCCESS (retries: 0)
# [Processing] Dòng 1749... SUCCESS (retries: 3)
# [CHECKPOINT] Đã lưu sau 50 dòng
# [Processing] Dòng 1750... SUCCESS (retries: 0)
# [Processing] Dòng 1751... SUCCESS (retries: 3)
# [Processing] Dòng 1752... SUCCESS (retries: 0)
# [Processing] Dòng 1753... SUCCESS (retries: 0)
# [Processing] Dòng 1754... SUCCESS (retries: 0)
# [Processing] Dòng 1755... SUCCESS (retries: 0)
# [Processing] Dòng 1756... SUCCESS (retries: 1)
# [Processing] Dòng 1757... SUCCESS (retries: 0)
# [Processing] Dòng 1758... SUCCESS (retries: 0)
# [Processing] Dòng 1759... SUCCESS (retries: 3)
# [Processing] Dòng 1760... SUCCESS (retries: 0)
# [Processing] Dòng 1761... SUCCESS (retries: 0)
# [Processing] Dòng 1762... SUCCESS (retries: 0)
# [Processing] Dòng 1763... SUCCESS (retries: 0)
# [Processing] Dòng 1764... SUCCESS (retries: 0)
# [Processing] Dòng 1765... SUCCESS (retries: 0)
# [Processing] Dòng 1766... SUCCESS (retries: 1)
# [Processing] Dòng 1767... SUCCESS (retries: 3)
# [Processing] Dòng 1768... SUCCESS (retries: 3)
# [Processing] Dòng 1769... SUCCESS (retries: 0)
# [Processing] Dòng 1770... SUCCESS (retries: 0)
# [Processing] Dòng 1771... SUCCESS (retries: 0)
# [Processing] Dòng 1772... SUCCESS (retries: 0)
# [Processing] Dòng 1773... SUCCESS (retries: 0)
# [Processing] Dòng 1774... SUCCESS (retries: 0)
# [Processing] Dòng 1775... SUCCESS (retries: 0)
# [Processing] Dòng 1776... SUCCESS (retries: 0)
# [Processing] Dòng 1777... SUCCESS (retries: 1)
# [Processing] Dòng 1778... SUCCESS (retries: 0)
# [Processing] Dòng 1779... SUCCESS (retries: 0)
# [Processing] Dòng 1780... SUCCESS (retries: 0)
# [Processing] Dòng 1781... SUCCESS (retries: 0)
# [Processing] Dòng 1782... SUCCESS (retries: 0)
# [Processing] Dòng 1783... SUCCESS (retries: 0)
# [Processing] Dòng 1784... SUCCESS (retries: 0)
# [Processing] Dòng 1785... SUCCESS (retries: 0)
# [Processing] Dòng 1786... SUCCESS (retries: 1)
# [Processing] Dòng 1787... SUCCESS (retries: 0)
# [Processing] Dòng 1788... SUCCESS (retries: 0)
# [Processing] Dòng 1789... SUCCESS (retries: 0)
# [Processing] Dòng 1790... SUCCESS (retries: 0)
# [Processing] Dòng 1791... SUCCESS (retries: 0)
# [Processing] Dòng 1792... SUCCESS (retries: 0)
# [Processing] Dòng 1793... SUCCESS (retries: 1)
# [Processing] Dòng 1794... SUCCESS (retries: 0)
# [Processing] Dòng 1795... SUCCESS (retries: 0)
# [Processing] Dòng 1796... SUCCESS (retries: 0)
# [Processing] Dòng 1797... SUCCESS (retries: 0)
# [Processing] Dòng 1798... SUCCESS (retries: 0)
# [Processing] Dòng 1799... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
#
# ================================================================================
# [LOG] Dòng 1700-1799
# ================================================================================
# Thành công:     100
# Error:          0
# Timeout Error:  0
# Tổng xử lý:     100
# Tiến độ:        1800/4833 (37.24%)
# Thời gian:      190.38 phút
# Ước tính còn:   320.79 phút
# ================================================================================
#
# [Processing] Dòng 1800... SUCCESS (retries: 0)
# [Processing] Dòng 1801... SUCCESS (retries: 0)
# [Processing] Dòng 1802... SUCCESS (retries: 0)
# [Processing] Dòng 1803... SUCCESS (retries: 0)
# [Processing] Dòng 1804... SUCCESS (retries: 0)
# [Processing] Dòng 1805... SUCCESS (retries: 0)
# [Processing] Dòng 1806... SUCCESS (retries: 0)
# [Processing] Dòng 1807... SUCCESS (retries: 0)
# [Processing] Dòng 1808... SUCCESS (retries: 0)
# [Processing] Dòng 1809... SUCCESS (retries: 0)
# [Processing] Dòng 1810... SUCCESS (retries: 0)
# [Processing] Dòng 1811... SUCCESS (retries: 0)
# [Processing] Dòng 1812... SUCCESS (retries: 0)
# [Processing] Dòng 1813... SUCCESS (retries: 0)
# [Processing] Dòng 1814... SUCCESS (retries: 0)
# [Processing] Dòng 1815... SUCCESS (retries: 0)
# [Processing] Dòng 1816... SUCCESS (retries: 3)
# [Processing] Dòng 1817... SUCCESS (retries: 0)
# [Processing] Dòng 1818... SUCCESS (retries: 2)
# [Processing] Dòng 1819... SUCCESS (retries: 0)
# [Processing] Dòng 1820... SUCCESS (retries: 0)
# [Processing] Dòng 1821... SUCCESS (retries: 0)
# [Processing] Dòng 1822... SUCCESS (retries: 0)
# [Processing] Dòng 1823... SUCCESS (retries: 3)
# [Processing] Dòng 1824... SUCCESS (retries: 1)
# [Processing] Dòng 1825... SUCCESS (retries: 0)
# [Processing] Dòng 1826... SUCCESS (retries: 3)
# [Processing] Dòng 1827... SUCCESS (retries: 2)
# [Processing] Dòng 1828... SUCCESS (retries: 3)
# [Processing] Dòng 1829... SUCCESS (retries: 0)
# [Processing] Dòng 1830... SUCCESS (retries: 0)
# [Processing] Dòng 1831... SUCCESS (retries: 0)
# [Processing] Dòng 1832... SUCCESS (retries: 3)
# [Processing] Dòng 1833... SUCCESS (retries: 0)
# [Processing] Dòng 1834... SUCCESS (retries: 0)
# [Processing] Dòng 1835... SUCCESS (retries: 3)
# [Processing] Dòng 1836... SUCCESS (retries: 1)
# [Processing] Dòng 1837... SUCCESS (retries: 0)
# [Processing] Dòng 1838... SUCCESS (retries: 0)
# [Processing] Dòng 1839... SUCCESS (retries: 0)
# [Processing] Dòng 1840... SUCCESS (retries: 2)
# [Processing] Dòng 1841... SUCCESS (retries: 3)
# [Processing] Dòng 1842... SUCCESS (retries: 2)
# [Processing] Dòng 1843... SUCCESS (retries: 1)
# [Processing] Dòng 1844... SUCCESS (retries: 1)
# [Processing] Dòng 1845... SUCCESS (retries: 0)
# [Processing] Dòng 1846... SUCCESS (retries: 0)
# [Processing] Dòng 1847... SUCCESS (retries: 0)
# [Processing] Dòng 1848... SUCCESS (retries: 0)
# [Processing] Dòng 1849... SUCCESS (retries: 0)
# [CHECKPOINT] Đã lưu sau 50 dòng
# [Processing] Dòng 1850... SUCCESS (retries: 0)
# [Processing] Dòng 1851... SUCCESS (retries: 1)
# [Processing] Dòng 1852... SUCCESS (retries: 3)
# [Processing] Dòng 1853...
